# %%
import pandas as pd
import numpy as np
import requests
import json
from pandas.io.json import json_normalize
from PIL import Image
from os import path
from bs4 import BeautifulSoup
import urllib.request
from urllib.request import urlopen
import re
import time
import aiohttp
import asyncio
from pathlib import Path
import asyncio
import sys

sys.path.append(path.abspath('MSc-CS-Project---ColourPaletteExtractor-master/'))
from colourpaletteextractor.model import model
# sys.path.append(path.abspath('old_color_palette_gen/MSc-CS-Project---ColourPaletteExtractor-master/'))
# from colourpaletteextractor.model import model

# %% [markdown]
# ### Tate Collection image scraper

# %%
# Local file dataset
# df = pd.read_json(r'the-tate-collection.json')
# df = pd.json_normalize(df['fields'])
# df
# recoloured_image, colour_palette, relative_frequencies = model.generate_colour_palette_from_image("image/A00544.jpg")
# colors = model.generate_colour_palette_from_image("image/A00544.jpg")
# colors

# %%
# recoloured_image
# colour_palette[0]
# relative_frequencies

# %%
# view image
# im = Image.open(requests.get("https://www.tate.org.uk/art/images/work/T/T08/T08333_10.jpg", stream = True).raw)
# im

# %%
# def url_get_int(url): 
#     url = url.split('_')[1]
#     url = url.split('.')[0]
#     return int(url)

# def binary_find_largest(arr):
#     temp_list = arr
#     length = len(temp_list)
#     if len(arr) == 1:
#         return temp_list[0]
#     elif url_get_int(temp_list[length - 1]) >= url_get_int(temp_list[length - 2]):
#         del temp_list[length - 2]
#     elif url_get_int(temp_list[length - 1]) <= url_get_int(temp_list[length - 2]):
#         del temp_list[length - 1]
    
#     return binary_find_largest(temp_list)
    
# def get_best_imageURL(number):
#     url = df['url'][number]
#     accession_number = df['accession_number'][number]
    
#     page = requests.get(url)
#     soup = BeautifulSoup(page.content, 'html.parser')
#     attrs = []
#     page.close()
    
#     for node in soup.findAll('img'):
#         attrs += list(node.attrs.values())
        
#     temp_images = [k for k in attrs if accession_number in k]
    
#     # returns NaN if no image avilable
#     if len(temp_images) == 0:
#         return np.nan
#     else:
#         return binary_find_largest(temp_images)

# %%
# new_df = pd.DataFrame(columns = ['img_URL', 'Colour_Palettes'])

# %%
# def set_df_img_url_range(start, last):
#     timer = time.process_time()
    
#     for counter in range(start, last + 1):
#         try:
#             url = get_best_imageURL(counter)
#             if url is not np.nan:
#                 savepath = Path("image/"+ str(df["accession_number"][counter]) + ".jpg")
#                 if not savepath.is_file():
#                     urllib.request.urlretrieve(url, savepath)
                
#                 if len(new_df) == counter:
#                     colors = model.generate_colour_palette_from_image(savepath)
#                 elif new_df.loc[counter]['Colour_Palettes'] is np.nan:
#                     colors = model.generate_colour_palette_from_image(savepath)

#                 new_df.loc[counter] = [url, colors]

#             else:
#                 new_df.loc[counter] = [url, np.nan]   

#         except:
#             print(str(counter))
#             counter -= 1
#             continue
    
#     print(time.process_time() - timer)

# %%
# set_df_img_url_range(0, 100)

# %%
# new_df

# %% [markdown]
# # ArtUK web scraping

# %%
# Link that has search settings set to the following
# Location: Scotland, Type: Painting, Topic: Seas and Coasts, Has image ticked, old to new
url = "https://artuk.org/discover/artworks/view_as/grid/search/has_image:on--region:scotland--work_type:painting--category:seas-and-coasts/sort_by/date_earliest/order/asc/page/1"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
page.close()
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
# 												Art UK | Discover Artworks 									</title>
# <meta content="" name="author"/>
# <meta content="Discover artworks, explore venues and meet artists. Art UK is the online home for every public collection in the UK. Featuring over 275,000 artworks by over 50,000 artists." name="description"/>
# <meta content="art, uk, art uk, nsw-rlrbwj98djuzr8je9lkikzom-numnw-a0xd1tjxmjqpgxb-2-8x1-ujelx-g77bi-fw64rhobgu0-7v3t-glh32vmekcliuy70l4olzmeqmwsbzhe9mc2msn8yphihiy" name="keywords"/>
# <meta content="width=320, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="https://artuk.org/skins/artuk/img/logo-share-red-bg.jpg" property="og:image"/>
# <meta content="https://artuk.org/skins/artuk/img/logo-share-red-bg.jpg" property="twitter:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="JIUbN6LLIebBDGBC7NmZWoRui_ClxYQ7_R7Obi7BhQM" name="google-site-verification">
# <meta content="4b5a2b6c2daf088afa3ba843c56ac138" name="p:domain_verify">
# <meta content="412367082176649" property="fb:pages">
# <script src="https://artuk.org/skins/artuk/js/modernizr.min.js"></script>
# <script src="https://artuk.org/skins/artuk/js/viewport-units-buggyfill.min.js"></script>
# <script>window.viewportUnitsBuggyfill.init();</script>
# <link href="https://artuk.org/skins/artuk/assets/css/style.min.css?v=4.8.0" media="screen" rel="stylesheet"/>
# <link href="https://artuk.org/skins/artuk/assets/css/print.min.css?v=4.8.0" media="print" rel="stylesheet"/>
# <link href="https://cdn.rawgit.com/toopay/bootstrap-markdown/master/css/bootstrap-markdown.min.css" rel="stylesheet"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_114px@2x.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_114px.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_72px.png" rel="apple-touch-icon-precomposed" sizes="72x72">
# <link href="https://artuk.org/skins/artuk/img/favicon_62px.png" rel="apple-touch-icon-precomposed" sizes="62x62">
# <link href="https://artuk.org/skins/artuk/img/favicon_57px.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_32px.png" rel="apple-touch-icon-precomposed" sizes="32x32"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_16px.png" rel="apple-touch-icon-precomposed" sizes="16x16"/>
# <link href="https://artuk.org/skins/artuk/img/favicon.ico" rel="shortcut icon" sizes="16x16" type="image/x-icon"/>
# <link href="https://unpkg.com/material-components-web@latest/dist/material-components-web.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://maxst.icons8.com/vue-static/landings/line-awesome/line-awesome/1.3.0/css/line-awesome.min.css" rel="stylesheet"/>
# <noscript>
# <style>
# 				#carousel li,.masonry .item,.twin{opacity:1}.drop-down ul,.js-hidden,.open-close .trigger+*{display:block}
# 			</style>
# </noscript>
# <!--[if lt IE 9]>
# 			<script src="https://artuk.org/skins/artuk/js/html5shiv.min.js"></script>
# 		<![endif]-->
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <!-- Hotjar Tracking Code for www.artuk.org -->
# <script>
# 		(function(h,o,t,j,a,r){
# 		h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
# 		h._hjSettings={hjid:355650,hjsv:6};
# 		a=o.getElementsByTagName('head')[0];
# 		r=o.createElement('script');r.async=1;
# 		r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# 		a.appendChild(r);
# 		})(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# 		</script>
# </link></link></meta></meta></meta></head>
# <body class="object desktop list_page">
# <!-- Google Tag Manager -->
# <script>
# 			dataLayer = [{"pageType":"artworks_listing_grid","loginStatus":"false","contentModules":[],"artworkId":null,"artworkName":"Artworks","artworkType":null}];
# 		</script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-M75FWJ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 				new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 				j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 				'//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 				})(window,document,'script','dataLayer','GTM-M75FWJ');</script>
# <map hidden="" id="skip-nav" name="skip-nav" title="Skip navigation">
# <p>
# 				[<a href="#content-body" title="Skip to content">Skip to content</a>]
# 									[<a href="#main-nav" title="Skip to main navigation">Skip to main navigation</a>]
# 																	[<a href="#footer-nav" title="Skip to quick links">Skip to quick links</a>]
# 								[<a accesskey="A" href="https://artuk.org/footer/accessibility" title="Go to accessibility information">Go to accessibility information</a>]
# 			</p>
# </map>
# <!-- skins/artuk/common/v_messages -->
# <div class="top-message-wrap" id="top-notice">
# <section class="top-message">
# <div class="row">
# <div>
# <p>Art UK has updated its cookies policy. By using this website you are agreeing to the use of cookies. To find out more read our updated <a href="http://artuk.org/footer/use-of-cookies-14">Use of Cookies policy</a> and our updated <a href="https://artuk.org/footer/privacy-policy">Privacy policy</a>.</p>
# </div>
# </div>
# <a class="close-button" href="#">Close</a>
# </section>
# </div>
# <!-- END: skins/artuk/common/v_messages -->
# <!-- artuk/navigation/v_main_navigation -->
# <nav class="navbar navbar-default">
# <div class="navbar-header fixed">
# <div class="navbar-header--container">
# <div class="navbar-logo__container">
# <div class="logo">
# <a href="https://artuk.org/">
# <svg height="40px" version="1.1" viewbox="0 0 115 40" width="115px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <!-- Generator: Sketch 43.2 (39069) - http://www.bohemiancoding.com/sketch -->
# <desc>Created with Sketch.</desc>
# <defs></defs>
# <g fill="none" fill-rule="evenodd" id="Home" stroke="none" stroke-width="1">
# <g fill="#FFFFFF" id="3.00-Home" transform="translate(-55.000000, -13.000000)">
# <g id="Group-5" transform="translate(55.000000, 13.000000)">
# <path d="M97.3981111,8.67818165 L97.3981111,7.73118693 L104.216634,7.73118693 C105.53222,7.73118693 106.536628,6.84152281 106.536628,5.23463198 C106.536628,3.62774115 105.53222,2.73792851 104.216634,2.73792851 L97.3981111,2.73792851 L97.3981111,1.79108231 L104.131701,1.79108231 C105.164371,1.79108231 105.970797,2.12110462 106.550685,2.79540764 C107.13072,3.45545227 107.413636,4.27323034 107.413636,5.23463198 C107.413636,6.19603362 107.13072,7.01381169 106.550685,7.68811471 C105.970797,8.34815934 105.164371,8.67818165 104.131701,8.67818165 L97.3981111,8.67818165" id="Fill-96" transform="translate(102.405873, 5.234632) rotate(-270.000000) translate(-102.405873, -5.234632) "></path>
# <polyline id="Fill-98" points="116.443588 1.96344043 116.443588 3.12564773 111.195304 7.44430608 116.443588 7.44430608 116.443588 8.39130081 106.541259 8.39130081 106.541259 7.44430608 110.771077 7.44430608 106.541259 3.52740757 106.541259 2.32212805 110.983118 6.43998075 116.443588 1.96344043" transform="translate(111.492424, 5.177371) rotate(-270.000000) translate(-111.492424, -5.177371) "></polyline>
# <polyline id="Fill-100" points="79.8859914 38.7276408 78.1261175 40.7030219 50.4791983 11.4060409 52.2390722 9.43065982 79.8859914 38.7276408" transform="translate(65.182595, 25.066841) rotate(-270.000000) translate(-65.182595, -25.066841) "></polyline>
# <path d="M34.0333098,33.7841148 L40.8383606,33.7841148 L40.8383606,28.3513712 C40.8383606,25.7887227 39.6930807,24.4901696 37.4359084,24.4901696 C35.1788826,24.4901696 34.0333098,25.7887227 34.0333098,28.3513712 L34.0333098,33.7841148 L34.0333098,33.7841148 Z M54.7854126,22.7818362 L43.668246,29.7864188 L43.668246,33.7841148 L54.7854126,33.7841148 L54.7854126,36.7910013 L31.2035708,36.7910013 L31.2035708,28.4195442 C31.2035708,24.0460801 33.3595554,21.3809494 37.4359084,21.3809494 C40.7711462,21.3809494 42.7924093,23.055122 43.4661637,26.3696036 L54.7854126,19.2282296 L54.7854126,22.7818362 L54.7854126,22.7818362 Z" id="Fill-102" transform="translate(42.994492, 28.009615) rotate(-270.000000) translate(-42.994492, -28.009615) "></path>
# <polyline id="Fill-104" points="78.5712932 31.0681073 75.7414078 31.0681073 75.7414078 13.1637283 78.5712932 13.1637283 78.5712932 20.6125488 99.3232496 20.6125488 99.3232496 23.6192868 78.5712932 23.6192868 78.5712932 31.0681073" transform="translate(87.532329, 22.115918) rotate(-270.000000) translate(-87.532329, -22.115918) "></polyline>
# <path d="M2.2887743,12.9693601 L12.9007349,16.6594611 L12.9007349,9.27911059 L2.2887743,12.9693601 L2.2887743,12.9693601 Z M-1.55166946,14.4044076 L-1.55166946,11.5343126 L22.0301723,3.02621254 L22.0301723,6.1355812 L15.7304739,8.2881525 L15.7304739,17.6504192 L22.0301723,19.803139 L22.0301723,22.9125077 L-1.55166946,14.4044076 L-1.55166946,14.4044076 Z" id="Fill-106" transform="translate(10.239251, 12.969360) rotate(-270.000000) translate(-10.239251, -12.969360) "></path>
# <polyline id="Fill-108" points="31.4955241 27.6419369 29.0230901 28.5513548 22.7717158 13.2084362 25.2787087 12.4196205 31.4955241 27.6419369" transform="translate(27.133620, 20.485488) rotate(-270.000000) translate(-27.133620, -20.485488) "></polyline>
# </g>
# </g>
# </g>
# </svg>
# </a>
# </div>
# </div>
# <div class="menu-toggle menu" id="menu-toggle">
# <div>Menu</div>
# <span></span>
# </div>
# <div class="menu-toggle account" id="account-toggle">
# <div>
# 			 			SIGN IN					</div>
# </div>
# <div class="menu-toggle search-menu" id="search-toggle">
# <div>
# 						Search					</div>
# </div>
# <a class="menu-toggle shop" href="https://artuk.org/shop">
# <div class="label">Shop</div>
# </a>
# <div class="navbar-home">
# <ul>
# <li>
# <a href="https://artuk.org/about/about">About</a>
# </li>
# <li>
# <a href="https://artuk.org/discover/discover">Discover</a>
# </li>
# <li>
# <a href="https://artuk.org/learn/learning-resources">Learn</a>
# </li>
# <li>
# <a href="https://artuk.org/support-us/support-us">Support us</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- <a id="donate-link" href="https://donate.artuk.org/make-a-donation.html?_ga=1.228818012.133081471.1456250831" target="_blank">
# 				<div class="donate">
# 					Donate
# 				</div>
# 			</a> -->
# <div class="main-navigation">
# <h2 class="sr-only">Main menu</h2>
# <div class="close-menu">Close</div>
# <ul class="menu main">
# <li class="home-item">
# <a href="https://artuk.org/">Home</a>
# </li>
# <li class="form-item">
# <h3 class="sr-only">Search form</h3>
# <form action="https://artuk.org/search/search" class="navbar-form navbar-left" id="nav-form-search" method="post">
# <div class="form-group">
# <label class="sr-only" for="main-search">Search</label>
# <div class="input-group">
# <input class="form-control" data-placeholder="Search" id="main-search" name="keyword" placeholder="Search" type="text"/>
# <div class="input-group-addon">
# <button type="submit"></button>
# </div>
# </div>
# </div>
# </form>
# </li>
# <ul class="submenu-collapse">
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#discover-0-child" role="button"></a>
# <a href="https://artuk.org/discover/discover" ref="discover" title="Discover">
# 											Discover										</a>
# </h3>
# <ul class="collapse" id="discover-0-child">
# <li class="active">
# <a accesskey="1" href="https://artuk.org/discover/artworks" ref="artworks" title="Artworks">
# 													Artworks												</a>
# </li>
# <li>
# <a accesskey="2" href="https://artuk.org/discover/artists" ref="artists" title="Artists">
# 													Artists												</a>
# </li>
# <li>
# <a accesskey="4" href="https://artuk.org/discover/topics" ref="topics" title="Topics">
# 													Topics												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/discover/art-terms" ref="art-terms" title="Art terms">
# 													Art terms												</a>
# </li>
# <li>
# <a accesskey="3" href="https://artuk.org/discover/stories" ref="stories" title="Stories">
# 													Stories												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/discover/curations" ref="curations" title="Curations">
# 													Curations												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#learn-7-child" role="button"></a>
# <a href="https://artuk.org/learn/learning-resources" ref="learning-resources" title="Learn">
# 											Learn										</a>
# </h3>
# <ul class="collapse" id="learn-7-child">
# <li>
# <a accesskey="" href="https://artuk.org/learn/learning-resources" ref="learning-resources" title="Learning resources">
# 													Learning resources												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/learn/write-on-art" ref="write-on-art" title="Write on Art">
# 													Write on Art												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#participate-10-child" role="button"></a>
# <a href="https://artuk.org/participate/participate" ref="participate" title="Participate">
# 											Participate										</a>
# </h3>
# <ul class="collapse" id="participate-10-child">
# <li>
# <a accesskey="" href="https://artuk.org/participate/volunteer" ref="volunteer" title="Volunteer">
# 													Volunteer												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/participate/curate" ref="curate" title="Curate">
# 													Curate												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/artdetective" ref="artdetective" title="Become an Art Detective">
# 													Art Detective
# 												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#visit-13-child" role="button"></a>
# <a href="https://artuk.org/visit/visit" ref="visit" title="Visit">
# 											Visit										</a>
# </h3>
# <ul class="collapse" id="visit-13-child">
# <li>
# <a accesskey="5" href="https://artuk.org/visit/venues" ref="venues" title="Venues">
# 													Venues												</a>
# </li>
# <li>
# <a accesskey="6" href="https://artuk.org/visit/whats-on" ref="whats-on" title="What's on">
# 													What's on												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#support-us-16-child" role="button"></a>
# <a href="https://artuk.org/support-us/support-us" ref="support-us" title="Support us">
# 											Support us										</a>
# </h3>
# <ul class="collapse" id="support-us-16-child">
# <li>
# <a accesskey="" href="https://artuk.org/support-us/why-support-art-uk" ref="why-support-art-uk" title="Why support Art UK?">
# 													Why support Art UK?												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/support-us/make-a-donation" ref="make-a-donation" title="Make a donation">
# 													Make a donation												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/support-us/individual-support" ref="individual-support" title="Individual support">
# 													Individual support												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/support-us/corporate-support" ref="corporate-support" title="Corporate support">
# 													Corporate support												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#about-21-child" role="button"></a>
# <a href="https://artuk.org/about/about" ref="about" title="About">
# 											About										</a>
# </h3>
# <ul class="collapse" id="about-21-child">
# <li>
# <a accesskey="" href="https://artuk.org/about/who-we-are" ref="who-we-are" title="Who we are">
# 													Who we are												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/about/what-we-do-199" ref="what-we-do-199" title="What we do">
# 													What we do												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/about/who-we-work-with" ref="who-we-work-with" title="Who we work with">
# 													Who we work with												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/about/who-funds-us" ref="who-funds-us" title="Who funds us">
# 													Who funds us												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#for-collections-26-child" role="button"></a>
# <a href="https://artuk.org/for-collections/for-collections" ref="for-collections" title="For collections">
# 											For collections										</a>
# </h3>
# <ul class="collapse" id="for-collections-26-child">
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/partner-collections" ref="partner-collections" title="Partner collections">
# 													Partner collections												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/collection-images-and-copyright" ref="collection-images-and-copyright" title="Collection images and copyright">
# 													Collection images and copyright												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/collections-portal" ref="collections-portal" title="Collections Portal">
# 													Collections Portal												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/curations-and-content" ref="curations-and-content" title="Curations and content">
# 													Curations and content												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/shop-and-commercial" ref="shop-and-commercial" title="Shop and commercial">
# 													Shop and commercial												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/collection-care-and-research" ref="collection-care-and-research" title="Collection care and research">
# 													Collection care and research												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/marketing-your-collection" ref="marketing-your-collection" title="Marketing your collection">
# 													Marketing your collection												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#Shop-child"></a>
# <!-- <a href="#Shop-child" data-toggle="collapse" class="collapsed">Shop</a> -->
# <a href="https://artuk.org/shop" ref="Shop" title="Shop">
# 									Shop								</a>
# </h3>
# <ul class="collapse" id="Shop-child">
# <li>
# <a href="https://artuk.org/shop/find-a-print.html">Prints</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/art-themes.html">Art themes</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/art-books.html">Books</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/gifts.html">Gifts</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/image-licences.html">Licensing</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/about.html">About the shop</a>
# </li>
# </ul>
# </li>
# </ul>
# </ul>
# <div class="account-menu">
# <ul class="nav nav-tabs" role="tablist">
# <li class="active" role="presentation"><a aria-controls="signin" data-toggle="tab" href="#signin" role="tab">Sign in</a></li>
# <li role="presentation"><a aria-controls="register" class="reg" data-toggle="tab" href="#register" role="tab">Register</a></li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane active" id="signin" role="tabpanel">
# <p>Sign in to access personalised features</p>
# <br/>
# <div class="signin-wrap">
# <!-- sign in form -->
# <form action="https://artuk.org/login" class="ajax-submit" data-form-validation-standard="" data-type="signin" id="nav-form-signin" method="post">
# <div class="form-error"></div>
# <div class="form-group">
# <label for="signin-email">Email address</label>
# <input class="form-control" data-validation="required" id="signin-email" name="signin-email" placeholder="Email" type="email"/>
# </div>
# <div class="form-group">
# <label for="signin-password">Password</label>
# <input autocomplete="password" class="form-control" data-validation="required" id="signin-password" name="signin-password" placeholder="Password" type="password"/>
# </div>
# <div class="form-group terms">
# <p><input name="remember-me" type="checkbox"/>Remember me (uncheck on a public computer)</p>
# </div>
# <div class="form-group terms">
# <p>By signing up you agree to <a class="link" href="http://www.artuk.org/footer/terms-of-use"><span>terms and conditions</span></a>
# 											and <a class="link" href="http://artuk.org/footer/privacy-policy"><span>privacy policy</span></a>
# </p>
# </div>
# <input class="btn btn-default action submit" type="submit" value="Sign in"/>
# </form>
# <a class="link forgotten" href="#"><span class="disabled">Forgotten password?</span></a>
# </div>
# <div class="forgotten-wrap">
# <form action="https://artuk.org/reset-password" class="ajax-submit" data-form-validation-standard="" data-type="forgotten">
# <p>Enter your email address below and we’ll send you a link to reset your password</p>
# <div class="form-error"></div>
# <div class="form-group">
# <label for="signin-email">Email address</label>
# <input class="form-control" data-validation="required" id="reset-email" name="reset-email" placeholder="Email" type="email"/>
# </div>
# <div class="g-recaptcha" data-sitekey="6LdOmpoUAAAAAH8lJfA7l7iHUFVW8VyLvE1Djhx5"></div>
# <br/>
# <input class="btn btn-default action submit" type="submit" value="Send">
# <a class="link forgotten-cancel" href="#"><span class="disabled">Cancel</span></a>
# </input></form>
# </div>
# </div>
# <div class="tab-pane" id="register" role="tabpanel">
# <p>Register to access personalised features</p>
# <br/>
# <!-- Register form -->
# <form action="https://artuk.org/register" class="ajax-submit" data-form-validation-standard="" data-type="register" id="nav-form-register" method="post">
# <div class="form-error"></div>
# <div class="form-group">
# <label for="register-firstname">First name</label>
# <input class="form-control" data-validation="required" id="register-firstname" name="register-firstname" type="text"/>
# </div>
# <div class="form-group">
# <label for="register-surname">Surname</label>
# <input class="form-control" data-validation="required" id="register-surname" name="register-surname" type="text"/>
# </div>
# <div class="form-group">
# <label for="register-email">Email address</label>
# <input class="form-control" data-validation="required" id="register-email" name="register-email" type="email"/>
# </div>
# <div class="form-group">
# <label for="register-password">Password</label>
# <input autocomplete="password" class="form-control" data-validation="required length" data-validation-length="min8" id="register-password" name="register-password" type="password"/>
# </div>
# <div class="form-group terms">
# <p><input data-validation="required" name="register-terms" type="checkbox"/>I agree to the Art UK <a class="link" href="http://www.artuk.org/footer/terms-of-use"><span>terms and conditions</span></a>
# 										and <a class="link" href="http://artuk.org/footer/privacy-policy"><span>privacy policy</span></a>
# </p>
# </div>
# <div class="form-group terms">
# <p><input name="register-partners" type="checkbox"/>My details can be shared with <a class="link" href="https://artuk.org/for-collections"><span>selected Art UK Partners</span></a></p>
# </div>
# <div class="form-group terms">
# <p><input name="register-subscribe" type="checkbox"/>Sign up to the Art UK newsletter</p>
# </div>
# <div class="g-recaptcha" data-sitekey="6LdOmpoUAAAAAH8lJfA7l7iHUFVW8VyLvE1Djhx5"></div>
# <br/>
# <input class="btn btn-default action submit" type="submit" value="Register"/>
# </form>
# </div>
# </div>
# </div>
# <div id="profile-menu">
# </div>
# </div>
# </div>
# </nav>
# <!-- END: artuk/navigation/v_main_navigation -->
# <!-- artuk/common/v_site_header_open -->
# <div class="header-wrap site-notice-visible">
# <header class="dark" id="header" style="background-image: url(https://d3d00swyhr67nd.cloudfront.net/_source/artuk_banner/ASH_ASHM_WA1997_discover.jpg); no-repeat;">
# <!-- END: artuk/common/v_site_header_open -->
# <!-- skins/artuk/common/v_page_title -->
# <div class="page-header">
# <p class="breadcrumb">Discover</p>
# <h2>
# 					Artworks			</h2>
# </div>
# <!-- END: skins/artuk/common/v_page_title --><!-- artuk/common/v_site_header_close -->
# <div id="credit">
# <p class="credit-content">
# <em>Murnau-Staffelsee I</em> (detail), 1908, oil on paper laid on board by Wassily Kandinsky (1866–1944), photo credit: The Ashmolean Museum of Art and Archaeology			</p>
# <a href="#">Credit</a>
# </div>
# </header>
# </div>
# <!-- END: artuk/common/v_site_header_close -->
# <main id="main">
# <!-- skins/artuk/common/v_advanced_filter -->
# <header data-fixed-header="" id="page-subsidiary">
# <section class="page-subsidiary">
# <div class="row">
# <form action="https://artuk.org/discover/artworks/view_as/grid" id="top-search" method="post">
# <div class="input-group main-search artworks_main">
# <div class="autocomplete artworks">
# <!-- Choose placeholder -->
# <input autocomplete="off" class="pad object artworks" data-api-url="https://artuk.org/api/autocomplete/object" data-autocomplete="true" data-placeholder="Refine your search" data-search-type="aggregation" data-type="object" id="filter_keyword" name="keyword" placeholder="Refine your search" type="text"/>
# <div class="input-group-addon">
# <button type="submit"></button>
# </div>
# <div class="autocomplete-menu">
# <div class="suggestion-header"><span>Search for "<span id="current-term"></span>"</span></div>
# <div id="autocomplete"></div>
# </div>
# </div>
# </div>
# <a class="show-filters">
# <i class="las la-sliders-h"></i>
# </a>
# <div class="main-tabs artworks_tabs">
# <ul class="nav nav-tabs" role="tablist">
# <li class="region" role="presentation">
# <a aria-controls="region" class="first_dropdown" href="#region" role="tab">
# <span>Location</span>
# </a>
# </li>
# <li class="work_type" role="presentation">
# <a aria-controls="work_type" class="" href="#work_type" role="tab">
# <span>Type</span>
# </a>
# </li>
# <li class="category_title" role="presentation">
# <a aria-controls="category_title" class="" href="#category_title" role="tab">
# <span>Topic</span>
# </a>
# </li>
# <li class="style_title" role="presentation">
# <a aria-controls="style_title" class="" href="#style_title" role="tab">
# <span>Style</span>
# </a>
# </li>
# <li class="licence" role="presentation">
# <a aria-controls="licence" class="" href="#licence" role="tab">
# <span>Licence</span>
# </a>
# </li>
# <li class="date-search">
# <div class="form-field">
# <div class="form-field__control">
# <input class="form-field__input" id="from" maxlength="4" min="0" name="date-from" placeholder=" " size="8" type="tel">
# <label class="form-field__label from" for="from">Year from</label>
# <div class="form-field__bar"></div>
# </input></div>
# </div>
# </li>
# <li class="date-search">
# <div class="form-field">
# <div class="form-field__control">
# <input class="form-field__input" id="to" maxlength="4" min="0" name="date-to" placeholder=" " size="6" type="tel">
# <label class="form-field__label to" for="to">Year to</label>
# <div class="form-field__bar"></div>
# </input></div>
# </div>
# </li>
# <li class="has-image" data-container="#page-subsidiary" data-placement="bottom" data-toggle="tooltip" data-trigger="hover" role="presentation" title="Show results without images">
# <input checked="checked" id="has-image" name="has_image" type="checkbox"/>
# <label class="" for="has-image">Has image</label>
# </li>
# <li class="outdoor-artwork" data-container="#page-subsidiary" data-placement="bottom" data-toggle="tooltip" data-trigger="hover" role="presentation" title="Show only outdoor artwork">
# <input id="outdoor-artwork" name="outdoor_artwork" type="checkbox"/>
# <label for="outdoor-artwork">Outdoor artwork</label>
# </li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane" id="region" role="tabpanel">
# <div class="location-search_wrapper">
# <div class="help-text">Search for a postcode or location where artworks are held</div>
# <div class="dropdown_miles-range">
# <a class="drop" href="#"><p class="miles-text">Within 5 miles</p><span class="arrow"></span></a>
# <ul class="dropdown-menu_miles-range">
# <li data-miles="0.25"><a href="#">Within ½ mile</a></li>
# <li data-miles="0.5"><a href="#">Within ¼ mile</a></li>
# <li data-miles="1"><a href="#">Within 1 mile</a></li>
# <li data-miles="3"><a href="#">Within 3 mile</a></li>
# <li data-miles="5"><a href="#">Within 5 miles</a></li>
# <li data-miles="10"><a href="#">Within 10 miles</a></li>
# <li data-miles="15"><a href="#">Within 15 miles</a></li>
# <li data-miles="20"><a href="#">Within 20 miles</a></li>
# </ul>
# </div>
# <div class="location-input">
# <div id="locationField">
# <input id="autocomplete-location" name="location_address" placeholder="Search a postcode or location..." type="text" value="">
# </input></div>
# <div class="input-group-addon location-search">
# <!-- TODO:  handle the click on icon differently -->
# <!-- <button id="location-btn" type="submit"></button> -->
# </div>
# </div>
# </div>
# <hr class="region-divider"/>
# <div class="help-text">Or choose region</div> <ul class="region" data-filter-tree="region"> <li><span class="disabled" data-group="region" data-label="Channel Islands" data-value="Channel Islands">Channel Islands</span><ul><li><span class="disabled" data-group="region" data-label="Alderney" data-value="Channel Islands.Alderney">Alderney</span></li><li><span class="disabled" data-group="region" data-label="Guernsey" data-value="Channel Islands.Guernsey">Guernsey</span></li><li><span class="disabled" data-group="region" data-label="Jersey" data-value="Channel Islands.Jersey">Jersey</span></li></ul></li><li><span class="disabled" data-group="region" data-label="England" data-value="England">England</span><ul><li><span class="disabled" data-group="region" data-label="East Midlands of England" data-value="England.East Midlands of England">East Midlands of England</span><ul><li><span class="disabled" data-group="region" data-label="Derbyshire" data-value="England.East Midlands of England.Derbyshire">Derbyshire</span></li><li><span class="disabled" data-group="region" data-label="Leicestershire" data-value="England.East Midlands of England.Leicestershire">Leicestershire</span></li><li><span class="disabled" data-group="region" data-label="Lincolnshire" data-value="England.East Midlands of England.Lincolnshire">Lincolnshire</span></li><li><span class="disabled" data-group="region" data-label="Northamptonshire" data-value="England.East Midlands of England.Northamptonshire">Northamptonshire</span></li><li><span class="disabled" data-group="region" data-label="Nottinghamshire" data-value="England.East Midlands of England.Nottinghamshire">Nottinghamshire</span></li><li><span class="disabled" data-group="region" data-label="Rutland" data-value="England.East Midlands of England.Rutland">Rutland</span></li></ul></li><li><span class="disabled" data-group="region" data-label="East of England" data-value="England.East of England">East of England</span><ul><li><span class="disabled" data-group="region" data-label="Bedfordshire" data-value="England.East of England.Bedfordshire">Bedfordshire</span></li><li><span class="disabled" data-group="region" data-label="Cambridgeshire" data-value="England.East of England.Cambridgeshire">Cambridgeshire</span></li><li><span class="disabled" data-group="region" data-label="Essex" data-value="England.East of England.Essex">Essex</span></li><li><span class="disabled" data-group="region" data-label="Hertfordshire" data-value="England.East of England.Hertfordshire">Hertfordshire</span></li><li><span class="disabled" data-group="region" data-label="Norfolk" data-value="England.East of England.Norfolk">Norfolk</span></li><li><span class="disabled" data-group="region" data-label="Suffolk" data-value="England.East of England.Suffolk">Suffolk</span></li></ul></li><li><span class="disabled" data-group="region" data-label="London" data-value="England.London">London</span><ul><li><span class="disabled" data-group="region" data-label="Central London" data-value="England.London.Central London">Central London</span></li><li><span class="disabled" data-group="region" data-label="East London" data-value="England.London.East London">East London</span></li><li><span class="disabled" data-group="region" data-label="North London" data-value="England.London.North London">North London</span></li><li><span class="disabled" data-group="region" data-label="North West London" data-value="England.London.North West London">North West London</span></li><li><span class="disabled" data-group="region" data-label="South East London" data-value="England.London.South East London">South East London</span></li><li><span class="disabled" data-group="region" data-label="South West London" data-value="England.London.South West London">South West London</span></li><li><span class="disabled" data-group="region" data-label="West London" data-value="England.London.West London">West London</span></li></ul></li><li><span class="disabled" data-group="region ...
# <div class="tab-pane" id="work_type" role="tabpanel">
# <ul class="work_type" data-filter-tree="work_type"> <li><span class="disabled" data-group="work_type" data-label="Drawing &amp; watercolour" data-value="Drawing &amp; watercolour">Drawing &amp; watercolour</span></li><li><span class="disabled" data-group="work_type" data-label="Mixed media &amp; collage" data-value="Mixed media &amp; collage">Mixed media &amp; collage</span></li><li><span class="disabled" data-group="work_type" data-label="Other" data-value="Other">Other</span><ul><li><span class="disabled" data-group="work_type" data-label="Architectural model or plan" data-value="Other.Architectural model or plan">Architectural model or plan</span></li><li><span class="disabled" data-group="work_type" data-label="Banner" data-value="Other.Banner">Banner</span></li><li><span class="disabled" data-group="work_type" data-label="Textile art" data-value="Other.Textile art">Textile art</span></li></ul></li><li><span class="active pass" data-group="work_type" data-label="Painting" data-value="Painting">Painting<i class="icon-tick"></i></span><ul><li><span class="disabled" data-group="work_type" data-label="Illuminated manuscript" data-value="Painting.Illuminated manuscript">Illuminated manuscript</span></li><li><span class="disabled" data-group="work_type" data-label="Miniature" data-value="Painting.Miniature">Miniature</span></li><li><span class="disabled" data-group="work_type" data-label="Mural or fresco" data-value="Painting.Mural or fresco">Mural or fresco</span></li><li><span class="disabled" data-group="work_type" data-label="Oleograph" data-value="Painting.Oleograph">Oleograph</span></li></ul></li><li><span class="disabled" data-group="work_type" data-label="Photograph" data-value="Photograph">Photograph</span></li><li><span class="disabled" data-group="work_type" data-label="Print" data-value="Print">Print</span><ul><li><span class="disabled" data-group="work_type" data-label="Poster" data-value="Print.Poster">Poster</span></li></ul></li><li><span class="disabled" data-group="work_type" data-label="Sculpture" data-value="Sculpture">Sculpture</span><ul><li><span class="disabled" data-group="work_type" data-label="Building" data-value="Sculpture.Building">Building</span></li><li><span class="disabled" data-group="work_type" data-label="Bust" data-value="Sculpture.Bust">Bust</span></li><li><span class="disabled" data-group="work_type" data-label="Clock tower" data-value="Sculpture.Clock tower">Clock tower</span></li><li><span class="disabled" data-group="work_type" data-label="Coat of arms" data-value="Sculpture.Coat of arms">Coat of arms</span></li><li><span class="disabled" data-group="work_type" data-label="Cross" data-value="Sculpture.Cross">Cross</span></li><li><span class="disabled" data-group="work_type" data-label="Equestrian" data-value="Sculpture.Equestrian">Equestrian</span></li><li><span class="disabled" data-group="work_type" data-label="Gateway" data-value="Sculpture.Gateway">Gateway</span></li><li><span class="disabled" data-group="work_type" data-label="Landscape" data-value="Sculpture.Landscape">Landscape</span></li><li><span class="disabled" data-group="work_type" data-label="Medallion" data-value="Sculpture.Medallion">Medallion</span></li><li><span class="disabled" data-group="work_type" data-label="Monument" data-value="Sculpture.Monument">Monument</span></li><li><span class="disabled" data-group="work_type" data-label="Mural" data-value="Sculpture.Mural">Mural</span></li><li><span class="disabled" data-group="work_type" data-label="Obelisk" data-value="Sculpture.Obelisk">Obelisk</span></li><li><span class="disabled" data-group="work_type" data-label="Other" data-value="Sculpture.Other">Other</span></li><li><span class="disabled" data-group="work_type" data-label="Panel" data-value="Sculpture.Panel">Panel</span></li><li><span class="disabled" data-group="work_type" data-label="Pylon" data-value="Sculpture.Pylon">Pylon</span></li><li><span class="disabled" data-group="work_type" data-label="Pyramid" data-va ...
# <div class="tab-pane" id="category_title" role="tabpanel">
# <ul class="category_title" data-filter-tree="category_title"> <li><span class="pass" data-group="category_title" data-label="Animals and plants" data-value="Animals and plants">Animals and plants</span><ul><li><span class="pass" data-group="category_title" data-label="Animals, domestic" data-value="Animals and plants.animals-domestic">Animals, domestic</span></li><li><span class="pass" data-group="category_title" data-label="Animals, farm" data-value="Animals and plants.animals-farm">Animals, farm</span></li><li><span class="pass" data-group="category_title" data-label="Animals, wild" data-value="Animals and plants.animals-wild">Animals, wild</span></li><li><span class="pass" data-group="category_title" data-label="Birds" data-value="Animals and plants.birds">Birds</span></li><li><span class="disabled" data-group="category_title" data-label="Cats" data-value="Animals and plants.cats">Cats</span></li><li><span class="pass" data-group="category_title" data-label="Dogs" data-value="Animals and plants.dogs">Dogs</span></li><li><span class="pass" data-group="category_title" data-label="Fish" data-value="Animals and plants.fish">Fish</span></li><li><span class="disabled" data-group="category_title" data-label="Fruit and vegetables" data-value="Animals and plants.fruit-and-vegetables">Fruit and vegetables</span></li><li><span class="pass" data-group="category_title" data-label="Horses " data-value="Animals and plants.horses">Horses </span></li><li><span class="disabled" data-group="category_title" data-label="Insects" data-value="Animals and plants.insects">Insects</span></li><li><span class="pass" data-group="category_title" data-label="Plants and flowers" data-value="Animals and plants.plants-and-flowers">Plants and flowers</span></li><li><span class="pass" data-group="category_title" data-label="Trees and shrubs" data-value="Animals and plants.trees-and-shrubs">Trees and shrubs</span></li></ul></li><li><span class="pass" data-group="category_title" data-label="Arts and entertainment" data-value="Arts and entertainment">Arts and entertainment</span><ul><li><span class="disabled" data-group="category_title" data-label="Architecture" data-value="Arts and entertainment.architecture">Architecture</span></li><li><span class="pass" data-group="category_title" data-label="Art" data-value="Arts and entertainment.art">Art</span></li><li><span class="disabled" data-group="category_title" data-label="Circuses, fairs and street entertainers" data-value="Arts and entertainment.circuses-fairs-and-street-entertainers">Circuses, fairs and street entertainers</span></li><li><span class="pass" data-group="category_title" data-label="Craft (art)" data-value="Arts and entertainment.craft-art">Craft (art)</span></li><li><span class="pass" data-group="category_title" data-label="Dance" data-value="Arts and entertainment.dance">Dance</span></li><li><span class="disabled" data-group="category_title" data-label="Film and photography" data-value="Arts and entertainment.film-and-photography">Film and photography</span></li><li><span class="pass" data-group="category_title" data-label="Music" data-value="Arts and entertainment.music">Music</span></li><li><span class="disabled" data-group="category_title" data-label="Reading and writing" data-value="Arts and entertainment.reading-and-writing">Reading and writing</span></li><li><span class="disabled" data-group="category_title" data-label="Theatre" data-value="Arts and entertainment.theatre">Theatre</span></li></ul></li><li><span class="pass" data-group="category_title" data-label="Fashion and costume" data-value="Fashion and costume">Fashion and costume</span><ul><li><span class="pass" data-group="category_title" data-label="Children's costume" data-value="Fashion and costume.childrens-costume">Children's costume</span></li><li><span class="pass" data-group="category_title" data-label="Drapery and classical costume" data-value="Fashion and costume.drapery-and-classical-costume">Drapery and classical costume</s ...
# <div class="tab-pane" id="style_title" role="tabpanel">
# <ul class="style_title" data-filter-tree="style_title"> <li><span class="disabled" data-group="style_title" data-label="Abstract Expressionism" data-value="Abstract Expressionism">Abstract Expressionism</span></li><li><span class="disabled" data-group="style_title" data-label="Abstraction" data-value="Abstraction">Abstraction</span></li><li><span class="disabled" data-group="style_title" data-label="Aestheticism" data-value="Aestheticism">Aestheticism</span></li><li><span class="disabled" data-group="style_title" data-label="Art Deco" data-value="Art Deco">Art Deco</span></li><li><span class="disabled" data-group="style_title" data-label="Art Nouveau" data-value="Art Nouveau">Art Nouveau</span></li><li><span class="disabled" data-group="style_title" data-label="Assemblage" data-value="Assemblage">Assemblage</span></li><li><span class="disabled" data-group="style_title" data-label="Barbizon School" data-value="Barbizon School">Barbizon School</span></li><li><span class="disabled" data-group="style_title" data-label="Baroque" data-value="Baroque">Baroque</span></li><li><span class="disabled" data-group="style_title" data-label="British Impressionism" data-value="British Impressionism">British Impressionism</span></li><li><span class="disabled" data-group="style_title" data-label="Caravaggism" data-value="Caravaggism">Caravaggism</span></li><li><span class="disabled" data-group="style_title" data-label="Caricature" data-value="Caricature">Caricature</span></li><li><span class="disabled" data-group="style_title" data-label="Carving" data-value="Carving">Carving</span></li><li><span class="disabled" data-group="style_title" data-label="Casting and bronze" data-value="Casting and bronze">Casting and bronze</span></li><li><span class="disabled" data-group="style_title" data-label="Celtic Revival" data-value="Celtic Revival">Celtic Revival</span></li><li><span class="disabled" data-group="style_title" data-label="Clay modelling" data-value="Clay modelling">Clay modelling</span></li><li><span class="disabled" data-group="style_title" data-label="Constructivism" data-value="Constructivism">Constructivism</span></li><li><span class="disabled" data-group="style_title" data-label="Cubism" data-value="Cubism">Cubism</span></li><li><span class="disabled" data-group="style_title" data-label="Dada" data-value="Dada">Dada</span></li><li><span class="disabled" data-group="style_title" data-label="Die Brücke" data-value="Die Brücke">Die Brücke</span></li><li><span class="disabled" data-group="style_title" data-label="Early Renaissance" data-value="Early Renaissance">Early Renaissance</span></li><li><span class="disabled" data-group="style_title" data-label="Expressionism" data-value="Expressionism">Expressionism</span></li><li><span class="disabled" data-group="style_title" data-label="Fauvism" data-value="Fauvism">Fauvism</span></li><li><span class="disabled" data-group="style_title" data-label="Figurative art" data-value="Figurative art">Figurative art</span></li><li><span class="pass" data-group="style_title" data-label="French Impressionism" data-value="French Impressionism">French Impressionism</span></li><li><span class="disabled" data-group="style_title" data-label="French Realism" data-value="French Realism">French Realism</span></li><li><span class="disabled" data-group="style_title" data-label="Futurism" data-value="Futurism">Futurism</span></li><li><span class="disabled" data-group="style_title" data-label="Glasgow Boys" data-value="Glasgow Boys">Glasgow Boys</span></li><li><span class="disabled" data-group="style_title" data-label="Glasgow Style" data-value="Glasgow Style">Glasgow Style</span></li><li><span class="disabled" data-group="style_title" data-label="Glass" data-value="Glass">Glass</span></li><li><span class="disabled" data-group="style_title" data-label="Grisaille" data-value="Grisaille">Grisaille</span></li><li><span class="disabled" data-group="style_title" data-label="High Renaissance" data-value="High Renaissance">High  ...
# <div class="tab-pane" id="licence" role="tabpanel">
# <ul class="licence" data-filter-tree="licence"> <li><span class="pass" data-group="licence" data-label="Search all images with an Open or Creative Commons Licence" data-value="1cc">Search all images with an Open or Creative Commons Licence</span></li><li><span class="pass" data-group="licence" data-label="Search all Public Domain images (PD and CC0)" data-value="2pd">Search all Public Domain images (PD and CC0)</span></li><li><span class="pass" data-group="licence" data-label="Search images with a Creative Commons licence" data-value="Search images with a Creative Commons licence">Search images with a Creative Commons licence</span><ul><li><span class="pass" data-group="licence" data-label="Any CC licence" data-value="Search images with a Creative Commons licence.0cc-only">Any CC licence</span></li><li><span class="pass" data-group="licence" data-label="Attribution (CC BY)" data-value="Search images with a Creative Commons licence.2cc-by">Attribution (CC BY)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-ShareAlike (CC BY-SA)" data-value="Search images with a Creative Commons licence.3cc-by-sa">Attribution-ShareAlike (CC BY-SA)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-NoDerivs (CC BY-ND)" data-value="Search images with a Creative Commons licence.4cc-by-nd">Attribution-NoDerivs (CC BY-ND)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-NonCommercial (CC BY-NC)" data-value="Search images with a Creative Commons licence.5cc-by-nc">Attribution-NonCommercial (CC BY-NC)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-NonCommercial-ShareAlike (CC BY-NC-SA)" data-value="Search images with a Creative Commons licence.6cc-by-nc-sa">Attribution-NonCommercial-ShareAlike (CC BY-NC-SA)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-Non-Commercial-NoDerivs (CC BY-NC-ND)" data-value="Search images with a Creative Commons licence.7cc-by-nc-nd">Attribution-Non-Commercial-NoDerivs (CC BY-NC-ND)</span></li></ul></li><li><span class="pass" data-group="licence" data-label="About Creative Commons and image use" data-value="licence_url_a_image">About Creative Commons and image use</span></li><li><span class="pass" data-group="licence" data-label="Search for high resolution images available for commercial licensing" data-value="licence_url_b_shop">Search for high resolution images available for commercial licensing</span></li></ul> </div>
# </div>
# </div>
# <div class="hidden" id="filter-values">
# <input id="group_region" name="region" type="" value="Scotland">
# <input id="group_work_type" name="work_type" type="" value="Painting">
# <input id="group_category_title" name="category_title" type="" value="">
# <input id="group_style_title" name="style_title" type="" value="">
# <input id="group_licence" name="licence" type="" value="">
# <input id="group_category" name="category" type="" value="seas-and-coasts">
# <input class="field" id="location_latitude" name="location_latitude" type="hidden" value="">
# ...
# <div class="wrap">
# <div class="img-wrap">
# <img alt="New Aberdeen" src="https://d3d00swyhr67nd.cloudfront.net/w300/collection/ABD/ABDC/ABD_ABDC_ag008214-001.jpg"/>
# <div class="actions">
# <div class="action-toggle">
# <a class="toggle fav ajax-action no-user" data-action="fav-artwork" data-add-fav="" data-original-title="Sign in to favourite" data-placement="top" data-title-add="Add to favourites" data-title-remove="Remove from favourites" data-toggle="tooltip-hover" href="https://artuk.org/favourite/new-aberdeen-107487" title=""></a>
# </div>
# <!-- skins/artuk/object/v_toolbar_curation-->
# <div class="album action-toggle toolbar_icon no-user" data-action-dropdown="">
# <div class="toggle album toolbar_icon" data-original-title="Sign in to curate" data-placement="top" data-toggle="tooltip-hover" title="Sign in to curate">
# </div>
# </div>
# <!-- skins/artuk/object/v_toolbar_curation-->
# </div>
# </div>
# <!-- -->
# </div>
#
# <div class="info">
# <div class="icons">
# </div>
# <span class="title">
# 											New Aberdeen																<span class="date">c.1807</span>
# </span>
# <span class="artist">
# 																Alexander Nasmyth (1758–1840)									</span>
# </div>
# <div class="more-info">
# <span class="title">
# 											New Aberdeen																<span class="date">c.1807</span>
# </span>
# <span class="artist">
# 						Aberdeen City Council Collection					</span>
# </div>
# </li>
# <!-- END: skins/artuk/object/list/v_list -->
# <!-- skins/artuk/stories/v_list_close -->
# </ul>
# <div class="pagination">
# <a class="btn btn-default pagination-btn" data-ajax-load="" data-page="1" href="https://artuk.org/discover/artworks/search/has_image:on--region:scotland--work_type:painting--category:seas-and-coasts/sort_by/date_earliest/order/asc/page/2"><span>Load more</span><div class="loader"><div></div><div></div><div></div></div></a>
# </div>
# <!-- TO DO
# 	<div class="no-results">
# 		There are no results for your search, please try altering your search crietia.
# 	</div>
# 	-->
# <div class="back-top"></div>
# </section>
# <!-- skins/artuk/stories/v_list_close -->
# </main>
# <footer id="footer">
# <!-- common/v_footer -->
# <div class="container-break">
# <nav>
# <h2 class="sr-only">Follow us</h2>
# <ul class="menu menu-social">
# <li>
# <ul>
# <li class="facebook">
# <a class="ext_hlink" href="https://www.facebook.com/artukdotorg" target="_blank" title="Join us on Facebook">Join us on Facebook</a>
# </li>
# <li class="twitter">
# <a class="ext_hlink" href="https://twitter.com/artukdotorg" target="_blank" title="Follow us on Twitter">Follow us on Twitter</a>
# </li>
# <li class="instagram">
# <a class="ext_hlink" href="https://www.instagram.com/artukdotorg/" target="_blank" title="Follow us on Instagram">
# <svg enable-background="new 0 0 50 50" height="50px" id="Layer_0" version="1.1" viewbox="0 0 50 50" width="50px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path clip-rule="evenodd" d="M45.516,16.492c-0.101-2.196-0.448-3.697-0.958-5.011
# 										c-0.527-1.356-1.233-2.509-2.383-3.655c-1.146-1.148-2.299-1.854-3.657-2.381c-1.311-0.511-2.812-0.86-5.01-0.959
# 										c-2.203-0.101-2.905-0.125-8.512-0.125s-6.31,0.023-8.511,0.125c-2.197,0.099-3.698,0.449-5.011,0.959
# 										c-1.357,0.528-2.509,1.233-3.656,2.381c-1.148,1.146-1.854,2.299-2.381,3.655c-0.511,1.314-0.86,2.815-0.959,5.011
# 										c-0.101,2.202-0.125,2.906-0.125,8.512s0.023,6.309,0.125,8.512c0.1,2.197,0.449,3.697,0.959,5.01
# 										c0.528,1.358,1.233,2.51,2.381,3.657c1.147,1.147,2.299,1.854,3.656,2.382c1.313,0.511,2.814,0.858,5.011,0.959
# 										c2.202,0.101,2.905,0.125,8.511,0.125s6.309-0.024,8.512-0.125c2.197-0.101,3.699-0.448,5.01-0.959
# 										c1.358-0.528,2.511-1.234,3.657-2.382c1.149-1.147,1.855-2.299,2.383-3.657c0.51-1.312,0.857-2.812,0.958-5.01
# 										c0.101-2.203,0.125-2.905,0.125-8.512S45.616,18.693,45.516,16.492z M41.802,33.347c-0.094,2.011-0.431,3.105-0.713,3.833
# 										c-0.373,0.963-0.819,1.65-1.542,2.373s-1.412,1.17-2.375,1.544c-0.728,0.282-1.82,0.619-3.833,0.711
# 										c-2.177,0.1-2.83,0.121-8.343,0.121c-5.512,0-6.165-0.021-8.341-0.121c-2.014-0.092-3.107-0.429-3.833-0.711
# 										c-0.964-0.374-1.652-0.821-2.374-1.544c-0.723-0.723-1.169-1.41-1.544-2.373c-0.283-0.728-0.619-1.822-0.71-3.833
# 										c-0.1-2.179-0.121-2.83-0.121-8.343c0-5.512,0.021-6.166,0.121-8.342c0.091-2.013,0.427-3.106,0.71-3.833
# 										c0.375-0.963,0.822-1.652,1.544-2.373c0.722-0.723,1.41-1.169,2.374-1.544c0.727-0.284,1.82-0.62,3.833-0.71
# 										c2.176-0.1,2.829-0.121,8.341-0.121c5.513,0,6.164,0.021,8.343,0.121c2.013,0.09,3.105,0.427,3.833,0.71
# 										c0.963,0.375,1.652,0.822,2.375,1.544c0.723,0.721,1.169,1.41,1.542,2.373c0.282,0.728,0.619,1.82,0.713,3.833
# 										c0.098,2.176,0.119,2.83,0.119,8.342C41.921,30.517,41.899,31.168,41.802,33.347z" fill-rule="evenodd"></path>
# <circle clip-rule="evenodd" cx="36.018" cy="13.984" fill-rule="evenodd" r="2.478"></circle>
# <path clip-rule="evenodd" d="M24.996,14.403c-5.854,0-10.601,4.746-10.601,10.601
# 										c0,5.855,4.747,10.601,10.601,10.601c5.855,0,10.601-4.745,10.601-10.601C35.597,19.149,30.852,14.403,24.996,14.403z
# 										M24.996,31.886c-3.801,0-6.881-3.082-6.881-6.882c0-3.801,3.08-6.882,6.881-6.882c3.802,0,6.882,3.081,6.882,6.882
# 										C31.878,28.804,28.798,31.886,24.996,31.886z" fill-rule="evenodd"></path>
# </g>
# </svg>
# </a>
# </li>
# <li class="youtube">
# <a class="ext_hlink" href="https://www.youtube.com/channel/UCeZPrwByVwluSMQKgNLvnkw" target="_blank" title="Follow us on YouTube">Follow us on YouTube</a>
# </li>
# <li class="apple-podcasts">
# <a class="ext_hlink" href="https://itunes.apple.com/gb/podcast/art-matters/id1343288276?mt=2 " target="_blank" title="Find us on Apple Podcasts">
# <svg enable-background="new 0 0 50 50" height="50px" id="Layer_1" version="1.1" viewbox="0 0 50 50" width="50px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M28.941,29.207c-0.817-0.861-2.252-1.416-3.945-1.416c-1.695,0-3.129,0.552-3.947,1.416
# 										c-0.418,0.42-0.675,0.977-0.722,1.566c-0.139,1.271-0.061,2.369,0.087,4.119c0.142,1.668,0.411,3.895,0.763,6.16
# 										c0.25,1.611,0.455,2.482,0.639,3.107c0.299,1.009,1.422,1.895,3.177,1.895c1.755,0,2.876-0.884,3.178-1.895
# 										c0.185-0.624,0.39-1.493,0.64-3.107c0.354-2.267,0.621-4.49,0.764-6.16c0.148-1.75,0.227-2.848,0.087-4.119
# 										C29.615,30.184,29.359,29.627,28.941,29.207z M20.543,21.529c0,2.463,1.996,4.457,4.457,4.457c2.46,0,4.456-1.995,4.456-4.457
# 										c0-2.461-1.995-4.456-4.456-4.456C22.54,17.073,20.543,19.07,20.543,21.529z M24.945,3.945C14.525,3.975,5.986,12.428,5.857,22.848
# 										C5.752,31.289,11.14,38.51,18.665,41.154c0.135,0.048,0.281-0.022,0.329-0.157c0.014-0.039,0.018-0.081,0.012-0.122
# 										c-0.1-0.656-0.192-1.312-0.277-1.962c-0.029-0.229-0.176-0.425-0.386-0.519C12.2,35.714,8.252,29.626,8.309,22.925
# 										c0.088-9.065,7.492-16.457,16.557-16.53c9.267-0.074,16.833,7.444,16.833,16.694c-0.008,6.644-3.946,12.653-10.035,15.308
# 										c-0.212,0.095-0.357,0.289-0.389,0.519c-0.086,0.655-0.178,1.308-0.275,1.96c-0.021,0.139,0.072,0.271,0.213,0.29
# 										c0.042,0.008,0.085,0.004,0.124-0.013c7.452-2.619,12.81-9.729,12.81-18.065C44.146,12.516,35.527,3.917,24.945,3.945z
# 										M24.6,12.729c5.731-0.22,10.558,4.248,10.777,9.98c0.004,0.129,0.007,0.258,0.007,0.387c0.003,2.866-1.186,5.604-3.278,7.562
# 										c-0.172,0.16-0.263,0.389-0.252,0.623c0.041,0.712,0.025,1.404-0.021,2.186c-0.008,0.141,0.099,0.26,0.237,0.268
# 										c0.057,0.004,0.111-0.014,0.156-0.043c3.506-2.387,5.604-6.354,5.605-10.596c-0.007-7.09-5.759-12.83-12.848-12.824
# 										c-0.161,0-0.323,0.002-0.484,0.01c-6.786,0.263-12.231,5.857-12.317,12.648c-0.054,4.301,2.051,8.344,5.606,10.764
# 										c0.114,0.078,0.27,0.05,0.348-0.063c0.031-0.047,0.047-0.104,0.043-0.159c-0.051-0.729-0.059-1.46-0.022-2.188
# 										c0.013-0.234-0.079-0.463-0.25-0.624c-2.165-2.022-3.357-4.88-3.274-7.841C14.798,17.361,19.147,12.96,24.6,12.729z"></path>
# </g>
# </svg>
# </a>
# </li>
# <li class="dots">
# <a class="ext_hlink" href="https://the-dots.com/pages/art-uk-123427" target="_blank" title="Find us on Dots">
# <svg enable-background="new 0 0 50 50" height="50px" id="Layer_2" version="1.1" viewbox="0 0 50 50" width="50px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path clip-rule="evenodd" d="M25,4.254C13.56,4.254,4.253,13.561,4.253,25S13.56,45.746,25,45.746
# 										c11.439,0,20.747-9.307,20.747-20.746S36.439,4.254,25,4.254z M25,43.229C14.948,43.229,6.771,35.051,6.771,25
# 										C6.771,14.948,14.948,6.771,25,6.771c10.051,0,18.229,8.178,18.229,18.229C43.229,35.051,35.051,43.229,25,43.229z" fill-rule="evenodd"></path>
# <circle clip-rule="evenodd" cx="25" cy="25" fill-rule="evenodd" r="2.527"></circle>
# <circle clip-rule="evenodd" cx="25" cy="17.417" fill-rule="evenodd" r="2.528"></circle>
# <circle clip-rule="evenodd" cx="17.417" cy="25" fill-rule="evenodd" r="2.527"></circle>
# <circle clip-rule="evenodd" cx="32.583" cy="25" fill-rule="evenodd" r="2.527"></circle>
# <circle clip-rule="evenodd" cx="25" cy="32.583" fill-rule="evenodd" r="2.528"></circle>
# </g>
# </svg>
# </a>
# </li>
# <li class="to-top"><a data-anchor="#header" href="#header" id="to-top">Top</a></li>
# </ul>
# </li>
# <li class="support subscribe">
# <a class="ext_hlink" href="https://artuk.org/about/subscribe-to-newsletter" title="Subscribe to newsletter ">Subscribe to newsletter</a>
# </li>
# <li class="support">
# <a class="ext_hlink" href="https://artuk.org/support-us/make-a-donation" target="_blank" title="Donate to Art UK ">Donate to Art UK</a>
# </li>
# </ul>
# <h2 class="sr-only">Quick links</h2>
# <ul class="menu menu-quick">
# <li>
# <a class="hlink" href="https://artuk.org/about/contact-us" title="Contact us">Contact us</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/faq" title="Go toFAQ">FAQ</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/terms-of-use" title="Go toTerms of use">Terms of use</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/privacy-policy" title="Go toPrivacy policy">Privacy policy</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/use-of-cookies-14" title="Go toUse of cookies">Use of cookies</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/copyright-notice-15" title="Go toCopyright notice">Copyright notice</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/disclaimer-17" title="Go toDisclaimer">Disclaimer</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/accessibility" title="Go toAccessibility">Accessibility</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/about/jobs" title="Go toJobs">Jobs</a>
# </li>
# </ul>
# <ul class="menu menu-quick">
# <li>
# <a class="hlink" href="https://artuk.org/shop" title="Go toShop">Shop</a>
# </li>
# <li>
# <a class="hlink" href="http://artuk.org/shop/contact.html" title="Go toShop contact">Shop contact</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/shop-terms-of-use-and-supply" title="Go toShop terms of use and supply">Shop terms of use and supply</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/shop/about/delivery-details.html" title="Go toDelivery details">Delivery details</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/website-credits" title="Go toWebsite credits">Website credits</a>
# </li>
# </ul>
# <ul class="menu menu-logo">
# <li>
# <h2 class="sr-only">Supported by</h2>
# <a class="ext_hlink" href="http://www.artscouncil.org.uk" target="_blank" title="Visit Arts Council website">
# <b hidden="">Arts Council</b><img alt="Arts Council" src="https://artuk.org/skins/artuk/img/footer-sponsors.png"/>
# </a>
# </li>
# <li class="heritage_logo">
# <img alt="heritage fund" src="https://artuk.org/skins/artuk/img/heritage-fund.png"/>
# </li>
# <li class="bloomberg_logo">
# <img alt="bloomberg" src="https://artuk.org/skins/artuk/img/bloomberg-white.png"/>
# </li>
# </ul>
# </nav>
# <div class="credits">
# <div class="trademark">
# <img src="https://artuk.org/skins/artuk/img/artuk-logo-white.png"/>® is a registered trade mark of the Public Catalogue Foundation.		</div>
# <div class="company">Art UK is the operating name of the Public Catalogue Foundation, a charity registered in England and Wales (1096185) and Scotland (SC048601).</div>
# </div>
# </div>
# <!-- END: common/v_footer --> </footer>
# <div class="bg-overlay"></div>
# <script type="text/javascript"> var show_survey_modal = false;</script>
# <script type="text/javascript">var show_survey_modal = true;</script>
# <div class="modal fade" id="survey-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <button aria-label="Close" class="close icon-close" data-dismiss="modal" type="button"></button>
# <div class="modal-body">
# <h1><center>Subscribe to our newsletter</center></h1>
# <img alt="(detail), c.1699, oil on canvas by Edwaert Collier (c.1640–c.1707)" class="img-responsive" src="https://d3d00swyhr67nd.cloudfront.net/w800h800/artuk/TATE_TATE_T03853_10_detail (1).jpg">
# <br/>
# <p><center>New stories, newly added artworks and shop offers delivered straight to your inbox every week.</center></p>
# <a class="btn btn-lg btn-primary" href="https://artuk.org/about/subscribe-to-newsletter" id="survey-link" target="_blank">Subscribe</a>
# <br/>
# <div class="center">
# <a class="link" href="#" id="no-thanks"><span>No thanks</span></a>
# </div>
# <br/>
# </img></div>
# </div>
# </div>
# </div>
# <script>
# 				var KT = {
# 		    config: {
# 		        base_url: "https://artuk.org/",
# 		        skin: "skins/artuk",
# 		        is_mobile: "",
# 		        http_protocol: "https://",
# 		        autocomplete: {
# 		        	api_url: "https://artuk.org/api/autocomplete",
# 		        	char_limit: 3,
# 		        	results_limit: 3,
# 		        	lang: {
# 			        	events: "Event",
# 						locations: "Venue",
# 						makers: "Artist",
# 						people: "People",
# 						places: "Places",
# 						terms: "Tags",
# 						works: "Title",
# 						additional: "Additional title information",
# 						identifier: "Accession number",
# 						acquisition: "Acquisition method",
# 						execution: "Execution date",
# 						medium: "Medium and support",
# 						description: "Description",
# 						artists: "Artist",
# 						collections: "Collection",
# 						address_postcode: "Postcode",
# 						postcode: "Postcode",
# 						curation: "Curation title",
# 						artist: "Artist",
# 						artwork: "Artwork",
# 						author: "Curated by",
# 						lrresource: "Title",
# 						lrartist: "Artist",
# 						lrtopic: "Topic",
# 						lrterm: "Art term"
#
# 		        	}
# 		        },
# 		        map_listing: {
# 		        	venues_api: "https://artuk.org/api/venues/object",
# 		        },
# 		        artwork_suffle_api: "https://artuk.org/discover/artworks",
#             google_maps_key: "AIzaSyAM99sM9aNS0rxwAhwsDijCc718PoGrge4",
# 		        cluster_gridSize: 65 // The grid size of a cluster in pixels.
# 		    },
# 		    lang: {
# 				p_artwork_drag_image_or_click_here: "Drag and drop or click this message to add images",
# 		    	p_val_error_artwork_img_size: "Image must be a minimum of 1,200 pixels in width or height",
# 		    	p_val_error_venue_logo_img_size:  "Image must be a minimum of 450 pixels in height"
# 		    },
# 		    subscribe_popup: true		};
# 		</script>
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyAM99sM9aNS0rxwAhwsDijCc718PoGrge4&amp;libraries=places&amp;v=weekly"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/lib_boundle.min.js?v=4.8.0"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/main_es6_boundle.min.js?v=4.8.0"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/main_boundle.min.js?v=4.8.0"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/portal_boundle.min.js?v=4.8.0"></script>
# <script src="https://cdn.rawgit.com/toopay/bootstrap-markdown/master/js/bootstrap-markdown.js"></script>
# <script data-require="marked@*" data-semver="0.3.1" src="https://cdnjs.cloudflare.com/ajax/libs/marked/0.3.1/marked.js"></script>
# </body>
# </html>

# %%
# get the number of images on the page currently
def num_ofimages_on_pg(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    page.close()
    nodes = [[node] for node in soup.findAll('li', {"class": "item artwork icons"})]
    return int(len(nodes))

# get the url that shows all image from the search
def get_URL_All_img(url):
    count = soup.find('span', {"class": "count"})
    num = count.find('span', {"class": "num"})
    max_page = int(int(num.contents[0]) / 20)
    return url.replace(url.split("/")[-1], str(max_page + 1))

# %%
# num_ofimages_on_pg(url)

# %%
# temp_url = get_URL_All_img(url)
# print(temp_url)
# num_ofimages_on_pg(temp_url)

# %%
# Artuk page with all images loaded
all_img_url = get_URL_All_img(url)
page = requests.get(all_img_url)
all_results = BeautifulSoup(page.content, 'html.parser')
page.close()
all_results
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
# 												Art UK | Discover Artworks 									</title>
# <meta content="" name="author"/>
# <meta content="Discover artworks, explore venues and meet artists. Art UK is the online home for every public collection in the UK. Featuring over 275,000 artworks by over 50,000 artists." name="description"/>
# <meta content="art, uk, art uk, nsw-rlrbwj98djuzr8je9lkikzom-numnw-a0xd1tjxmjqpgxb-2-8x1-ujelx-g77bi-fw64rhobgu0-7v3t-glh32vmekcliuy70l4olzmeqmwsbzhe9mc2msn8yphihiy" name="keywords"/>
# <meta content="width=320, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="https://artuk.org/skins/artuk/img/logo-share-red-bg.jpg" property="og:image"/>
# <meta content="https://artuk.org/skins/artuk/img/logo-share-red-bg.jpg" property="twitter:image"/>
# <meta content="image/jpg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="JIUbN6LLIebBDGBC7NmZWoRui_ClxYQ7_R7Obi7BhQM" name="google-site-verification">
# <meta content="4b5a2b6c2daf088afa3ba843c56ac138" name="p:domain_verify">
# <meta content="412367082176649" property="fb:pages">
# <script src="https://artuk.org/skins/artuk/js/modernizr.min.js"></script>
# <script src="https://artuk.org/skins/artuk/js/viewport-units-buggyfill.min.js"></script>
# <script>window.viewportUnitsBuggyfill.init();</script>
# <link href="https://artuk.org/skins/artuk/assets/css/style.min.css?v=4.8.0" media="screen" rel="stylesheet"/>
# <link href="https://artuk.org/skins/artuk/assets/css/print.min.css?v=4.8.0" media="print" rel="stylesheet"/>
# <link href="https://cdn.rawgit.com/toopay/bootstrap-markdown/master/css/bootstrap-markdown.min.css" rel="stylesheet"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_114px@2x.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_114px.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_72px.png" rel="apple-touch-icon-precomposed" sizes="72x72">
# <link href="https://artuk.org/skins/artuk/img/favicon_62px.png" rel="apple-touch-icon-precomposed" sizes="62x62">
# <link href="https://artuk.org/skins/artuk/img/favicon_57px.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_32px.png" rel="apple-touch-icon-precomposed" sizes="32x32"/>
# <link href="https://artuk.org/skins/artuk/img/favicon_16px.png" rel="apple-touch-icon-precomposed" sizes="16x16"/>
# <link href="https://artuk.org/skins/artuk/img/favicon.ico" rel="shortcut icon" sizes="16x16" type="image/x-icon"/>
# <link href="https://unpkg.com/material-components-web@latest/dist/material-components-web.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://maxst.icons8.com/vue-static/landings/line-awesome/line-awesome/1.3.0/css/line-awesome.min.css" rel="stylesheet"/>
# <noscript>
# <style>
# 				#carousel li,.masonry .item,.twin{opacity:1}.drop-down ul,.js-hidden,.open-close .trigger+*{display:block}
# 			</style>
# </noscript>
# <!--[if lt IE 9]>
# 			<script src="https://artuk.org/skins/artuk/js/html5shiv.min.js"></script>
# 		<![endif]-->
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <!-- Hotjar Tracking Code for www.artuk.org -->
# <script>
# 		(function(h,o,t,j,a,r){
# 		h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
# 		h._hjSettings={hjid:355650,hjsv:6};
# 		a=o.getElementsByTagName('head')[0];
# 		r=o.createElement('script');r.async=1;
# 		r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# 		a.appendChild(r);
# 		})(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# 		</script>
# </link></link></meta></meta></meta></head>
# <body class="object desktop list_page">
# <!-- Google Tag Manager -->
# <script>
# 			dataLayer = [{"pageType":"artworks_listing_grid","loginStatus":"false","contentModules":[],"artworkId":null,"artworkName":"Artworks","artworkType":null}];
# 		</script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-M75FWJ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 				new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 				j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 				'//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 				})(window,document,'script','dataLayer','GTM-M75FWJ');</script>
# <map hidden="" id="skip-nav" name="skip-nav" title="Skip navigation">
# <p>
# 				[<a href="#content-body" title="Skip to content">Skip to content</a>]
# 									[<a href="#main-nav" title="Skip to main navigation">Skip to main navigation</a>]
# 																	[<a href="#footer-nav" title="Skip to quick links">Skip to quick links</a>]
# 								[<a accesskey="A" href="https://artuk.org/footer/accessibility" title="Go to accessibility information">Go to accessibility information</a>]
# 			</p>
# </map>
# <!-- skins/artuk/common/v_messages -->
# <div class="top-message-wrap" id="top-notice">
# <section class="top-message">
# <div class="row">
# <div>
# <p>Art UK has updated its cookies policy. By using this website you are agreeing to the use of cookies. To find out more read our updated <a href="http://artuk.org/footer/use-of-cookies-14">Use of Cookies policy</a> and our updated <a href="https://artuk.org/footer/privacy-policy">Privacy policy</a>.</p>
# </div>
# </div>
# <a class="close-button" href="#">Close</a>
# </section>
# </div>
# <!-- END: skins/artuk/common/v_messages -->
# <!-- artuk/navigation/v_main_navigation -->
# <nav class="navbar navbar-default">
# <div class="navbar-header fixed">
# <div class="navbar-header--container">
# <div class="navbar-logo__container">
# <div class="logo">
# <a href="https://artuk.org/">
# <svg height="40px" version="1.1" viewbox="0 0 115 40" width="115px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <!-- Generator: Sketch 43.2 (39069) - http://www.bohemiancoding.com/sketch -->
# <desc>Created with Sketch.</desc>
# <defs></defs>
# <g fill="none" fill-rule="evenodd" id="Home" stroke="none" stroke-width="1">
# <g fill="#FFFFFF" id="3.00-Home" transform="translate(-55.000000, -13.000000)">
# <g id="Group-5" transform="translate(55.000000, 13.000000)">
# <path d="M97.3981111,8.67818165 L97.3981111,7.73118693 L104.216634,7.73118693 C105.53222,7.73118693 106.536628,6.84152281 106.536628,5.23463198 C106.536628,3.62774115 105.53222,2.73792851 104.216634,2.73792851 L97.3981111,2.73792851 L97.3981111,1.79108231 L104.131701,1.79108231 C105.164371,1.79108231 105.970797,2.12110462 106.550685,2.79540764 C107.13072,3.45545227 107.413636,4.27323034 107.413636,5.23463198 C107.413636,6.19603362 107.13072,7.01381169 106.550685,7.68811471 C105.970797,8.34815934 105.164371,8.67818165 104.131701,8.67818165 L97.3981111,8.67818165" id="Fill-96" transform="translate(102.405873, 5.234632) rotate(-270.000000) translate(-102.405873, -5.234632) "></path>
# <polyline id="Fill-98" points="116.443588 1.96344043 116.443588 3.12564773 111.195304 7.44430608 116.443588 7.44430608 116.443588 8.39130081 106.541259 8.39130081 106.541259 7.44430608 110.771077 7.44430608 106.541259 3.52740757 106.541259 2.32212805 110.983118 6.43998075 116.443588 1.96344043" transform="translate(111.492424, 5.177371) rotate(-270.000000) translate(-111.492424, -5.177371) "></polyline>
# <polyline id="Fill-100" points="79.8859914 38.7276408 78.1261175 40.7030219 50.4791983 11.4060409 52.2390722 9.43065982 79.8859914 38.7276408" transform="translate(65.182595, 25.066841) rotate(-270.000000) translate(-65.182595, -25.066841) "></polyline>
# <path d="M34.0333098,33.7841148 L40.8383606,33.7841148 L40.8383606,28.3513712 C40.8383606,25.7887227 39.6930807,24.4901696 37.4359084,24.4901696 C35.1788826,24.4901696 34.0333098,25.7887227 34.0333098,28.3513712 L34.0333098,33.7841148 L34.0333098,33.7841148 Z M54.7854126,22.7818362 L43.668246,29.7864188 L43.668246,33.7841148 L54.7854126,33.7841148 L54.7854126,36.7910013 L31.2035708,36.7910013 L31.2035708,28.4195442 C31.2035708,24.0460801 33.3595554,21.3809494 37.4359084,21.3809494 C40.7711462,21.3809494 42.7924093,23.055122 43.4661637,26.3696036 L54.7854126,19.2282296 L54.7854126,22.7818362 L54.7854126,22.7818362 Z" id="Fill-102" transform="translate(42.994492, 28.009615) rotate(-270.000000) translate(-42.994492, -28.009615) "></path>
# <polyline id="Fill-104" points="78.5712932 31.0681073 75.7414078 31.0681073 75.7414078 13.1637283 78.5712932 13.1637283 78.5712932 20.6125488 99.3232496 20.6125488 99.3232496 23.6192868 78.5712932 23.6192868 78.5712932 31.0681073" transform="translate(87.532329, 22.115918) rotate(-270.000000) translate(-87.532329, -22.115918) "></polyline>
# <path d="M2.2887743,12.9693601 L12.9007349,16.6594611 L12.9007349,9.27911059 L2.2887743,12.9693601 L2.2887743,12.9693601 Z M-1.55166946,14.4044076 L-1.55166946,11.5343126 L22.0301723,3.02621254 L22.0301723,6.1355812 L15.7304739,8.2881525 L15.7304739,17.6504192 L22.0301723,19.803139 L22.0301723,22.9125077 L-1.55166946,14.4044076 L-1.55166946,14.4044076 Z" id="Fill-106" transform="translate(10.239251, 12.969360) rotate(-270.000000) translate(-10.239251, -12.969360) "></path>
# <polyline id="Fill-108" points="31.4955241 27.6419369 29.0230901 28.5513548 22.7717158 13.2084362 25.2787087 12.4196205 31.4955241 27.6419369" transform="translate(27.133620, 20.485488) rotate(-270.000000) translate(-27.133620, -20.485488) "></polyline>
# </g>
# </g>
# </g>
# </svg>
# </a>
# </div>
# </div>
# <div class="menu-toggle menu" id="menu-toggle">
# <div>Menu</div>
# <span></span>
# </div>
# <div class="menu-toggle account" id="account-toggle">
# <div>
# 			 			SIGN IN					</div>
# </div>
# <div class="menu-toggle search-menu" id="search-toggle">
# <div>
# 						Search					</div>
# </div>
# <a class="menu-toggle shop" href="https://artuk.org/shop">
# <div class="label">Shop</div>
# </a>
# <div class="navbar-home">
# <ul>
# <li>
# <a href="https://artuk.org/about/about">About</a>
# </li>
# <li>
# <a href="https://artuk.org/discover/discover">Discover</a>
# </li>
# <li>
# <a href="https://artuk.org/learn/learning-resources">Learn</a>
# </li>
# <li>
# <a href="https://artuk.org/support-us/support-us">Support us</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- <a id="donate-link" href="https://donate.artuk.org/make-a-donation.html?_ga=1.228818012.133081471.1456250831" target="_blank">
# 				<div class="donate">
# 					Donate
# 				</div>
# 			</a> -->
# <div class="main-navigation">
# <h2 class="sr-only">Main menu</h2>
# <div class="close-menu">Close</div>
# <ul class="menu main">
# <li class="home-item">
# <a href="https://artuk.org/">Home</a>
# </li>
# <li class="form-item">
# <h3 class="sr-only">Search form</h3>
# <form action="https://artuk.org/search/search" class="navbar-form navbar-left" id="nav-form-search" method="post">
# <div class="form-group">
# <label class="sr-only" for="main-search">Search</label>
# <div class="input-group">
# <input class="form-control" data-placeholder="Search" id="main-search" name="keyword" placeholder="Search" type="text"/>
# <div class="input-group-addon">
# <button type="submit"></button>
# </div>
# </div>
# </div>
# </form>
# </li>
# <ul class="submenu-collapse">
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#discover-0-child" role="button"></a>
# <a href="https://artuk.org/discover/discover" ref="discover" title="Discover">
# 											Discover										</a>
# </h3>
# <ul class="collapse" id="discover-0-child">
# <li class="active">
# <a accesskey="1" href="https://artuk.org/discover/artworks" ref="artworks" title="Artworks">
# 													Artworks												</a>
# </li>
# <li>
# <a accesskey="2" href="https://artuk.org/discover/artists" ref="artists" title="Artists">
# 													Artists												</a>
# </li>
# <li>
# <a accesskey="4" href="https://artuk.org/discover/topics" ref="topics" title="Topics">
# 													Topics												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/discover/art-terms" ref="art-terms" title="Art terms">
# 													Art terms												</a>
# </li>
# <li>
# <a accesskey="3" href="https://artuk.org/discover/stories" ref="stories" title="Stories">
# 													Stories												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/discover/curations" ref="curations" title="Curations">
# 													Curations												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#learn-7-child" role="button"></a>
# <a href="https://artuk.org/learn/learning-resources" ref="learning-resources" title="Learn">
# 											Learn										</a>
# </h3>
# <ul class="collapse" id="learn-7-child">
# <li>
# <a accesskey="" href="https://artuk.org/learn/learning-resources" ref="learning-resources" title="Learning resources">
# 													Learning resources												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/learn/write-on-art" ref="write-on-art" title="Write on Art">
# 													Write on Art												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#participate-10-child" role="button"></a>
# <a href="https://artuk.org/participate/participate" ref="participate" title="Participate">
# 											Participate										</a>
# </h3>
# <ul class="collapse" id="participate-10-child">
# <li>
# <a accesskey="" href="https://artuk.org/participate/volunteer" ref="volunteer" title="Volunteer">
# 													Volunteer												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/participate/curate" ref="curate" title="Curate">
# 													Curate												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/artdetective" ref="artdetective" title="Become an Art Detective">
# 													Art Detective
# 												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#visit-13-child" role="button"></a>
# <a href="https://artuk.org/visit/visit" ref="visit" title="Visit">
# 											Visit										</a>
# </h3>
# <ul class="collapse" id="visit-13-child">
# <li>
# <a accesskey="5" href="https://artuk.org/visit/venues" ref="venues" title="Venues">
# 													Venues												</a>
# </li>
# <li>
# <a accesskey="6" href="https://artuk.org/visit/whats-on" ref="whats-on" title="What's on">
# 													What's on												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#support-us-16-child" role="button"></a>
# <a href="https://artuk.org/support-us/support-us" ref="support-us" title="Support us">
# 											Support us										</a>
# </h3>
# <ul class="collapse" id="support-us-16-child">
# <li>
# <a accesskey="" href="https://artuk.org/support-us/why-support-art-uk" ref="why-support-art-uk" title="Why support Art UK?">
# 													Why support Art UK?												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/support-us/make-a-donation" ref="make-a-donation" title="Make a donation">
# 													Make a donation												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/support-us/individual-support" ref="individual-support" title="Individual support">
# 													Individual support												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/support-us/corporate-support" ref="corporate-support" title="Corporate support">
# 													Corporate support												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#about-21-child" role="button"></a>
# <a href="https://artuk.org/about/about" ref="about" title="About">
# 											About										</a>
# </h3>
# <ul class="collapse" id="about-21-child">
# <li>
# <a accesskey="" href="https://artuk.org/about/who-we-are" ref="who-we-are" title="Who we are">
# 													Who we are												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/about/what-we-do-199" ref="what-we-do-199" title="What we do">
# 													What we do												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/about/who-we-work-with" ref="who-we-work-with" title="Who we work with">
# 													Who we work with												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/about/who-funds-us" ref="who-funds-us" title="Who funds us">
# 													Who funds us												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#for-collections-26-child" role="button"></a>
# <a href="https://artuk.org/for-collections/for-collections" ref="for-collections" title="For collections">
# 											For collections										</a>
# </h3>
# <ul class="collapse" id="for-collections-26-child">
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/partner-collections" ref="partner-collections" title="Partner collections">
# 													Partner collections												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/collection-images-and-copyright" ref="collection-images-and-copyright" title="Collection images and copyright">
# 													Collection images and copyright												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/collections-portal" ref="collections-portal" title="Collections Portal">
# 													Collections Portal												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/curations-and-content" ref="curations-and-content" title="Curations and content">
# 													Curations and content												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/shop-and-commercial" ref="shop-and-commercial" title="Shop and commercial">
# 													Shop and commercial												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/collection-care-and-research" ref="collection-care-and-research" title="Collection care and research">
# 													Collection care and research												</a>
# </li>
# <li>
# <a accesskey="" href="https://artuk.org/for-collections/marketing-your-collection" ref="marketing-your-collection" title="Marketing your collection">
# 													Marketing your collection												</a>
# </li>
# </ul>
# </li>
# <li>
# <h3>
# <a class="collapsed toggle-icon" data-toggle="collapse" href="#Shop-child"></a>
# <!-- <a href="#Shop-child" data-toggle="collapse" class="collapsed">Shop</a> -->
# <a href="https://artuk.org/shop" ref="Shop" title="Shop">
# 									Shop								</a>
# </h3>
# <ul class="collapse" id="Shop-child">
# <li>
# <a href="https://artuk.org/shop/find-a-print.html">Prints</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/art-themes.html">Art themes</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/art-books.html">Books</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/gifts.html">Gifts</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/image-licences.html">Licensing</a>
# </li>
# <li>
# <a href="https://artuk.org/shop/about.html">About the shop</a>
# </li>
# </ul>
# </li>
# </ul>
# </ul>
# <div class="account-menu">
# <ul class="nav nav-tabs" role="tablist">
# <li class="active" role="presentation"><a aria-controls="signin" data-toggle="tab" href="#signin" role="tab">Sign in</a></li>
# <li role="presentation"><a aria-controls="register" class="reg" data-toggle="tab" href="#register" role="tab">Register</a></li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane active" id="signin" role="tabpanel">
# <p>Sign in to access personalised features</p>
# <br/>
# <div class="signin-wrap">
# <!-- sign in form -->
# <form action="https://artuk.org/login" class="ajax-submit" data-form-validation-standard="" data-type="signin" id="nav-form-signin" method="post">
# <div class="form-error"></div>
# <div class="form-group">
# <label for="signin-email">Email address</label>
# <input class="form-control" data-validation="required" id="signin-email" name="signin-email" placeholder="Email" type="email"/>
# </div>
# <div class="form-group">
# <label for="signin-password">Password</label>
# <input autocomplete="password" class="form-control" data-validation="required" id="signin-password" name="signin-password" placeholder="Password" type="password"/>
# </div>
# <div class="form-group terms">
# <p><input name="remember-me" type="checkbox"/>Remember me (uncheck on a public computer)</p>
# </div>
# <div class="form-group terms">
# <p>By signing up you agree to <a class="link" href="http://www.artuk.org/footer/terms-of-use"><span>terms and conditions</span></a>
# 											and <a class="link" href="http://artuk.org/footer/privacy-policy"><span>privacy policy</span></a>
# </p>
# </div>
# <input class="btn btn-default action submit" type="submit" value="Sign in"/>
# </form>
# <a class="link forgotten" href="#"><span class="disabled">Forgotten password?</span></a>
# </div>
# <div class="forgotten-wrap">
# <form action="https://artuk.org/reset-password" class="ajax-submit" data-form-validation-standard="" data-type="forgotten">
# <p>Enter your email address below and we’ll send you a link to reset your password</p>
# <div class="form-error"></div>
# <div class="form-group">
# <label for="signin-email">Email address</label>
# <input class="form-control" data-validation="required" id="reset-email" name="reset-email" placeholder="Email" type="email"/>
# </div>
# <div class="g-recaptcha" data-sitekey="6LdOmpoUAAAAAH8lJfA7l7iHUFVW8VyLvE1Djhx5"></div>
# <br/>
# <input class="btn btn-default action submit" type="submit" value="Send">
# <a class="link forgotten-cancel" href="#"><span class="disabled">Cancel</span></a>
# </input></form>
# </div>
# </div>
# <div class="tab-pane" id="register" role="tabpanel">
# <p>Register to access personalised features</p>
# <br/>
# <!-- Register form -->
# <form action="https://artuk.org/register" class="ajax-submit" data-form-validation-standard="" data-type="register" id="nav-form-register" method="post">
# <div class="form-error"></div>
# <div class="form-group">
# <label for="register-firstname">First name</label>
# <input class="form-control" data-validation="required" id="register-firstname" name="register-firstname" type="text"/>
# </div>
# <div class="form-group">
# <label for="register-surname">Surname</label>
# <input class="form-control" data-validation="required" id="register-surname" name="register-surname" type="text"/>
# </div>
# <div class="form-group">
# <label for="register-email">Email address</label>
# <input class="form-control" data-validation="required" id="register-email" name="register-email" type="email"/>
# </div>
# <div class="form-group">
# <label for="register-password">Password</label>
# <input autocomplete="password" class="form-control" data-validation="required length" data-validation-length="min8" id="register-password" name="register-password" type="password"/>
# </div>
# <div class="form-group terms">
# <p><input data-validation="required" name="register-terms" type="checkbox"/>I agree to the Art UK <a class="link" href="http://www.artuk.org/footer/terms-of-use"><span>terms and conditions</span></a>
# 										and <a class="link" href="http://artuk.org/footer/privacy-policy"><span>privacy policy</span></a>
# </p>
# </div>
# <div class="form-group terms">
# <p><input name="register-partners" type="checkbox"/>My details can be shared with <a class="link" href="https://artuk.org/for-collections"><span>selected Art UK Partners</span></a></p>
# </div>
# <div class="form-group terms">
# <p><input name="register-subscribe" type="checkbox"/>Sign up to the Art UK newsletter</p>
# </div>
# <div class="g-recaptcha" data-sitekey="6LdOmpoUAAAAAH8lJfA7l7iHUFVW8VyLvE1Djhx5"></div>
# <br/>
# <input class="btn btn-default action submit" type="submit" value="Register"/>
# </form>
# </div>
# </div>
# </div>
# <div id="profile-menu">
# </div>
# </div>
# </div>
# </nav>
# <!-- END: artuk/navigation/v_main_navigation -->
# <!-- artuk/common/v_site_header_open -->
# <div class="header-wrap site-notice-visible">
# <header class="dark" id="header" style="background-image: url(https://d3d00swyhr67nd.cloudfront.net/_source/artuk_banner/ASH_ASHM_WA1997_discover.jpg); no-repeat;">
# <!-- END: artuk/common/v_site_header_open -->
# <!-- skins/artuk/common/v_page_title -->
# <div class="page-header">
# <p class="breadcrumb">Discover</p>
# <h2>
# 					Artworks			</h2>
# </div>
# <!-- END: skins/artuk/common/v_page_title --><!-- artuk/common/v_site_header_close -->
# <div id="credit">
# <p class="credit-content">
# <em>Murnau-Staffelsee I</em> (detail), 1908, oil on paper laid on board by Wassily Kandinsky (1866–1944), photo credit: The Ashmolean Museum of Art and Archaeology			</p>
# <a href="#">Credit</a>
# </div>
# </header>
# </div>
# <!-- END: artuk/common/v_site_header_close -->
# <main id="main">
# <!-- skins/artuk/common/v_advanced_filter -->
# <header data-fixed-header="" id="page-subsidiary">
# <section class="page-subsidiary">
# <div class="row">
# <form action="https://artuk.org/discover/artworks/view_as/grid" id="top-search" method="post">
# <div class="input-group main-search artworks_main">
# <div class="autocomplete artworks">
# <!-- Choose placeholder -->
# <input autocomplete="off" class="pad object artworks" data-api-url="https://artuk.org/api/autocomplete/object" data-autocomplete="true" data-placeholder="Refine your search" data-search-type="aggregation" data-type="object" id="filter_keyword" name="keyword" placeholder="Refine your search" type="text"/>
# <div class="input-group-addon">
# <button type="submit"></button>
# </div>
# <div class="autocomplete-menu">
# <div class="suggestion-header"><span>Search for "<span id="current-term"></span>"</span></div>
# <div id="autocomplete"></div>
# </div>
# </div>
# </div>
# <a class="show-filters">
# <i class="las la-sliders-h"></i>
# </a>
# <div class="main-tabs artworks_tabs">
# <ul class="nav nav-tabs" role="tablist">
# <li class="region" role="presentation">
# <a aria-controls="region" class="first_dropdown" href="#region" role="tab">
# <span>Location</span>
# </a>
# </li>
# <li class="work_type" role="presentation">
# <a aria-controls="work_type" class="" href="#work_type" role="tab">
# <span>Type</span>
# </a>
# </li>
# <li class="category_title" role="presentation">
# <a aria-controls="category_title" class="" href="#category_title" role="tab">
# <span>Topic</span>
# </a>
# </li>
# <li class="style_title" role="presentation">
# <a aria-controls="style_title" class="" href="#style_title" role="tab">
# <span>Style</span>
# </a>
# </li>
# <li class="licence" role="presentation">
# <a aria-controls="licence" class="" href="#licence" role="tab">
# <span>Licence</span>
# </a>
# </li>
# <li class="date-search">
# <div class="form-field">
# <div class="form-field__control">
# <input class="form-field__input" id="from" maxlength="4" min="0" name="date-from" placeholder=" " size="8" type="tel">
# <label class="form-field__label from" for="from">Year from</label>
# <div class="form-field__bar"></div>
# </input></div>
# </div>
# </li>
# <li class="date-search">
# <div class="form-field">
# <div class="form-field__control">
# <input class="form-field__input" id="to" maxlength="4" min="0" name="date-to" placeholder=" " size="6" type="tel">
# <label class="form-field__label to" for="to">Year to</label>
# <div class="form-field__bar"></div>
# </input></div>
# </div>
# </li>
# <li class="has-image" data-container="#page-subsidiary" data-placement="bottom" data-toggle="tooltip" data-trigger="hover" role="presentation" title="Show results without images">
# <input checked="checked" id="has-image" name="has_image" type="checkbox"/>
# <label class="" for="has-image">Has image</label>
# </li>
# <li class="outdoor-artwork" data-container="#page-subsidiary" data-placement="bottom" data-toggle="tooltip" data-trigger="hover" role="presentation" title="Show only outdoor artwork">
# <input id="outdoor-artwork" name="outdoor_artwork" type="checkbox"/>
# <label for="outdoor-artwork">Outdoor artwork</label>
# </li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane" id="region" role="tabpanel">
# <div class="location-search_wrapper">
# <div class="help-text">Search for a postcode or location where artworks are held</div>
# <div class="dropdown_miles-range">
# <a class="drop" href="#"><p class="miles-text">Within 5 miles</p><span class="arrow"></span></a>
# <ul class="dropdown-menu_miles-range">
# <li data-miles="0.25"><a href="#">Within ½ mile</a></li>
# <li data-miles="0.5"><a href="#">Within ¼ mile</a></li>
# <li data-miles="1"><a href="#">Within 1 mile</a></li>
# <li data-miles="3"><a href="#">Within 3 mile</a></li>
# <li data-miles="5"><a href="#">Within 5 miles</a></li>
# <li data-miles="10"><a href="#">Within 10 miles</a></li>
# <li data-miles="15"><a href="#">Within 15 miles</a></li>
# <li data-miles="20"><a href="#">Within 20 miles</a></li>
# </ul>
# </div>
# <div class="location-input">
# <div id="locationField">
# <input id="autocomplete-location" name="location_address" placeholder="Search a postcode or location..." type="text" value="">
# </input></div>
# <div class="input-group-addon location-search">
# <!-- TODO:  handle the click on icon differently -->
# <!-- <button id="location-btn" type="submit"></button> -->
# </div>
# </div>
# </div>
# <hr class="region-divider"/>
# <div class="help-text">Or choose region</div> <ul class="region" data-filter-tree="region"> <li><span class="disabled" data-group="region" data-label="Channel Islands" data-value="Channel Islands">Channel Islands</span><ul><li><span class="disabled" data-group="region" data-label="Alderney" data-value="Channel Islands.Alderney">Alderney</span></li><li><span class="disabled" data-group="region" data-label="Guernsey" data-value="Channel Islands.Guernsey">Guernsey</span></li><li><span class="disabled" data-group="region" data-label="Jersey" data-value="Channel Islands.Jersey">Jersey</span></li></ul></li><li><span class="disabled" data-group="region" data-label="England" data-value="England">England</span><ul><li><span class="disabled" data-group="region" data-label="East Midlands of England" data-value="England.East Midlands of England">East Midlands of England</span><ul><li><span class="disabled" data-group="region" data-label="Derbyshire" data-value="England.East Midlands of England.Derbyshire">Derbyshire</span></li><li><span class="disabled" data-group="region" data-label="Leicestershire" data-value="England.East Midlands of England.Leicestershire">Leicestershire</span></li><li><span class="disabled" data-group="region" data-label="Lincolnshire" data-value="England.East Midlands of England.Lincolnshire">Lincolnshire</span></li><li><span class="disabled" data-group="region" data-label="Northamptonshire" data-value="England.East Midlands of England.Northamptonshire">Northamptonshire</span></li><li><span class="disabled" data-group="region" data-label="Nottinghamshire" data-value="England.East Midlands of England.Nottinghamshire">Nottinghamshire</span></li><li><span class="disabled" data-group="region" data-label="Rutland" data-value="England.East Midlands of England.Rutland">Rutland</span></li></ul></li><li><span class="disabled" data-group="region" data-label="East of England" data-value="England.East of England">East of England</span><ul><li><span class="disabled" data-group="region" data-label="Bedfordshire" data-value="England.East of England.Bedfordshire">Bedfordshire</span></li><li><span class="disabled" data-group="region" data-label="Cambridgeshire" data-value="England.East of England.Cambridgeshire">Cambridgeshire</span></li><li><span class="disabled" data-group="region" data-label="Essex" data-value="England.East of England.Essex">Essex</span></li><li><span class="disabled" data-group="region" data-label="Hertfordshire" data-value="England.East of England.Hertfordshire">Hertfordshire</span></li><li><span class="disabled" data-group="region" data-label="Norfolk" data-value="England.East of England.Norfolk">Norfolk</span></li><li><span class="disabled" data-group="region" data-label="Suffolk" data-value="England.East of England.Suffolk">Suffolk</span></li></ul></li><li><span class="disabled" data-group="region" data-label="London" data-value="England.London">London</span><ul><li><span class="disabled" data-group="region" data-label="Central London" data-value="England.London.Central London">Central London</span></li><li><span class="disabled" data-group="region" data-label="East London" data-value="England.London.East London">East London</span></li><li><span class="disabled" data-group="region" data-label="North London" data-value="England.London.North London">North London</span></li><li><span class="disabled" data-group="region" data-label="North West London" data-value="England.London.North West London">North West London</span></li><li><span class="disabled" data-group="region" data-label="South East London" data-value="England.London.South East London">South East London</span></li><li><span class="disabled" data-group="region" data-label="South West London" data-value="England.London.South West London">South West London</span></li><li><span class="disabled" data-group="region" data-label="West London" data-value="England.London.West London">West London</span></li></ul></li><li><span class="disabled" data-group="region ...
# <div class="tab-pane" id="work_type" role="tabpanel">
# <ul class="work_type" data-filter-tree="work_type"> <li><span class="disabled" data-group="work_type" data-label="Drawing &amp; watercolour" data-value="Drawing &amp; watercolour">Drawing &amp; watercolour</span></li><li><span class="disabled" data-group="work_type" data-label="Mixed media &amp; collage" data-value="Mixed media &amp; collage">Mixed media &amp; collage</span></li><li><span class="disabled" data-group="work_type" data-label="Other" data-value="Other">Other</span><ul><li><span class="disabled" data-group="work_type" data-label="Architectural model or plan" data-value="Other.Architectural model or plan">Architectural model or plan</span></li><li><span class="disabled" data-group="work_type" data-label="Banner" data-value="Other.Banner">Banner</span></li><li><span class="disabled" data-group="work_type" data-label="Textile art" data-value="Other.Textile art">Textile art</span></li></ul></li><li><span class="active pass" data-group="work_type" data-label="Painting" data-value="Painting">Painting<i class="icon-tick"></i></span><ul><li><span class="disabled" data-group="work_type" data-label="Illuminated manuscript" data-value="Painting.Illuminated manuscript">Illuminated manuscript</span></li><li><span class="disabled" data-group="work_type" data-label="Miniature" data-value="Painting.Miniature">Miniature</span></li><li><span class="disabled" data-group="work_type" data-label="Mural or fresco" data-value="Painting.Mural or fresco">Mural or fresco</span></li><li><span class="disabled" data-group="work_type" data-label="Oleograph" data-value="Painting.Oleograph">Oleograph</span></li></ul></li><li><span class="disabled" data-group="work_type" data-label="Photograph" data-value="Photograph">Photograph</span></li><li><span class="disabled" data-group="work_type" data-label="Print" data-value="Print">Print</span><ul><li><span class="disabled" data-group="work_type" data-label="Poster" data-value="Print.Poster">Poster</span></li></ul></li><li><span class="disabled" data-group="work_type" data-label="Sculpture" data-value="Sculpture">Sculpture</span><ul><li><span class="disabled" data-group="work_type" data-label="Building" data-value="Sculpture.Building">Building</span></li><li><span class="disabled" data-group="work_type" data-label="Bust" data-value="Sculpture.Bust">Bust</span></li><li><span class="disabled" data-group="work_type" data-label="Clock tower" data-value="Sculpture.Clock tower">Clock tower</span></li><li><span class="disabled" data-group="work_type" data-label="Coat of arms" data-value="Sculpture.Coat of arms">Coat of arms</span></li><li><span class="disabled" data-group="work_type" data-label="Cross" data-value="Sculpture.Cross">Cross</span></li><li><span class="disabled" data-group="work_type" data-label="Equestrian" data-value="Sculpture.Equestrian">Equestrian</span></li><li><span class="disabled" data-group="work_type" data-label="Gateway" data-value="Sculpture.Gateway">Gateway</span></li><li><span class="disabled" data-group="work_type" data-label="Landscape" data-value="Sculpture.Landscape">Landscape</span></li><li><span class="disabled" data-group="work_type" data-label="Medallion" data-value="Sculpture.Medallion">Medallion</span></li><li><span class="disabled" data-group="work_type" data-label="Monument" data-value="Sculpture.Monument">Monument</span></li><li><span class="disabled" data-group="work_type" data-label="Mural" data-value="Sculpture.Mural">Mural</span></li><li><span class="disabled" data-group="work_type" data-label="Obelisk" data-value="Sculpture.Obelisk">Obelisk</span></li><li><span class="disabled" data-group="work_type" data-label="Other" data-value="Sculpture.Other">Other</span></li><li><span class="disabled" data-group="work_type" data-label="Panel" data-value="Sculpture.Panel">Panel</span></li><li><span class="disabled" data-group="work_type" data-label="Pylon" data-value="Sculpture.Pylon">Pylon</span></li><li><span class="disabled" data-group="work_type" data-label="Pyramid" data-va ...
# <div class="tab-pane" id="category_title" role="tabpanel">
# <ul class="category_title" data-filter-tree="category_title"> <li><span class="pass" data-group="category_title" data-label="Animals and plants" data-value="Animals and plants">Animals and plants</span><ul><li><span class="pass" data-group="category_title" data-label="Animals, domestic" data-value="Animals and plants.animals-domestic">Animals, domestic</span></li><li><span class="pass" data-group="category_title" data-label="Animals, farm" data-value="Animals and plants.animals-farm">Animals, farm</span></li><li><span class="pass" data-group="category_title" data-label="Animals, wild" data-value="Animals and plants.animals-wild">Animals, wild</span></li><li><span class="pass" data-group="category_title" data-label="Birds" data-value="Animals and plants.birds">Birds</span></li><li><span class="disabled" data-group="category_title" data-label="Cats" data-value="Animals and plants.cats">Cats</span></li><li><span class="pass" data-group="category_title" data-label="Dogs" data-value="Animals and plants.dogs">Dogs</span></li><li><span class="pass" data-group="category_title" data-label="Fish" data-value="Animals and plants.fish">Fish</span></li><li><span class="disabled" data-group="category_title" data-label="Fruit and vegetables" data-value="Animals and plants.fruit-and-vegetables">Fruit and vegetables</span></li><li><span class="pass" data-group="category_title" data-label="Horses " data-value="Animals and plants.horses">Horses </span></li><li><span class="disabled" data-group="category_title" data-label="Insects" data-value="Animals and plants.insects">Insects</span></li><li><span class="pass" data-group="category_title" data-label="Plants and flowers" data-value="Animals and plants.plants-and-flowers">Plants and flowers</span></li><li><span class="pass" data-group="category_title" data-label="Trees and shrubs" data-value="Animals and plants.trees-and-shrubs">Trees and shrubs</span></li></ul></li><li><span class="pass" data-group="category_title" data-label="Arts and entertainment" data-value="Arts and entertainment">Arts and entertainment</span><ul><li><span class="disabled" data-group="category_title" data-label="Architecture" data-value="Arts and entertainment.architecture">Architecture</span></li><li><span class="pass" data-group="category_title" data-label="Art" data-value="Arts and entertainment.art">Art</span></li><li><span class="disabled" data-group="category_title" data-label="Circuses, fairs and street entertainers" data-value="Arts and entertainment.circuses-fairs-and-street-entertainers">Circuses, fairs and street entertainers</span></li><li><span class="pass" data-group="category_title" data-label="Craft (art)" data-value="Arts and entertainment.craft-art">Craft (art)</span></li><li><span class="pass" data-group="category_title" data-label="Dance" data-value="Arts and entertainment.dance">Dance</span></li><li><span class="disabled" data-group="category_title" data-label="Film and photography" data-value="Arts and entertainment.film-and-photography">Film and photography</span></li><li><span class="pass" data-group="category_title" data-label="Music" data-value="Arts and entertainment.music">Music</span></li><li><span class="disabled" data-group="category_title" data-label="Reading and writing" data-value="Arts and entertainment.reading-and-writing">Reading and writing</span></li><li><span class="disabled" data-group="category_title" data-label="Theatre" data-value="Arts and entertainment.theatre">Theatre</span></li></ul></li><li><span class="pass" data-group="category_title" data-label="Fashion and costume" data-value="Fashion and costume">Fashion and costume</span><ul><li><span class="pass" data-group="category_title" data-label="Children's costume" data-value="Fashion and costume.childrens-costume">Children's costume</span></li><li><span class="pass" data-group="category_title" data-label="Drapery and classical costume" data-value="Fashion and costume.drapery-and-classical-costume">Drapery and classical costume</s ...
# <div class="tab-pane" id="style_title" role="tabpanel">
# <ul class="style_title" data-filter-tree="style_title"> <li><span class="disabled" data-group="style_title" data-label="Abstract Expressionism" data-value="Abstract Expressionism">Abstract Expressionism</span></li><li><span class="disabled" data-group="style_title" data-label="Abstraction" data-value="Abstraction">Abstraction</span></li><li><span class="disabled" data-group="style_title" data-label="Aestheticism" data-value="Aestheticism">Aestheticism</span></li><li><span class="disabled" data-group="style_title" data-label="Art Deco" data-value="Art Deco">Art Deco</span></li><li><span class="disabled" data-group="style_title" data-label="Art Nouveau" data-value="Art Nouveau">Art Nouveau</span></li><li><span class="disabled" data-group="style_title" data-label="Assemblage" data-value="Assemblage">Assemblage</span></li><li><span class="disabled" data-group="style_title" data-label="Barbizon School" data-value="Barbizon School">Barbizon School</span></li><li><span class="disabled" data-group="style_title" data-label="Baroque" data-value="Baroque">Baroque</span></li><li><span class="disabled" data-group="style_title" data-label="British Impressionism" data-value="British Impressionism">British Impressionism</span></li><li><span class="disabled" data-group="style_title" data-label="Caravaggism" data-value="Caravaggism">Caravaggism</span></li><li><span class="disabled" data-group="style_title" data-label="Caricature" data-value="Caricature">Caricature</span></li><li><span class="disabled" data-group="style_title" data-label="Carving" data-value="Carving">Carving</span></li><li><span class="disabled" data-group="style_title" data-label="Casting and bronze" data-value="Casting and bronze">Casting and bronze</span></li><li><span class="disabled" data-group="style_title" data-label="Celtic Revival" data-value="Celtic Revival">Celtic Revival</span></li><li><span class="disabled" data-group="style_title" data-label="Clay modelling" data-value="Clay modelling">Clay modelling</span></li><li><span class="disabled" data-group="style_title" data-label="Constructivism" data-value="Constructivism">Constructivism</span></li><li><span class="disabled" data-group="style_title" data-label="Cubism" data-value="Cubism">Cubism</span></li><li><span class="disabled" data-group="style_title" data-label="Dada" data-value="Dada">Dada</span></li><li><span class="disabled" data-group="style_title" data-label="Die Brücke" data-value="Die Brücke">Die Brücke</span></li><li><span class="disabled" data-group="style_title" data-label="Early Renaissance" data-value="Early Renaissance">Early Renaissance</span></li><li><span class="disabled" data-group="style_title" data-label="Expressionism" data-value="Expressionism">Expressionism</span></li><li><span class="disabled" data-group="style_title" data-label="Fauvism" data-value="Fauvism">Fauvism</span></li><li><span class="disabled" data-group="style_title" data-label="Figurative art" data-value="Figurative art">Figurative art</span></li><li><span class="pass" data-group="style_title" data-label="French Impressionism" data-value="French Impressionism">French Impressionism</span></li><li><span class="disabled" data-group="style_title" data-label="French Realism" data-value="French Realism">French Realism</span></li><li><span class="disabled" data-group="style_title" data-label="Futurism" data-value="Futurism">Futurism</span></li><li><span class="disabled" data-group="style_title" data-label="Glasgow Boys" data-value="Glasgow Boys">Glasgow Boys</span></li><li><span class="disabled" data-group="style_title" data-label="Glasgow Style" data-value="Glasgow Style">Glasgow Style</span></li><li><span class="disabled" data-group="style_title" data-label="Glass" data-value="Glass">Glass</span></li><li><span class="disabled" data-group="style_title" data-label="Grisaille" data-value="Grisaille">Grisaille</span></li><li><span class="disabled" data-group="style_title" data-label="High Renaissance" data-value="High Renaissance">High  ...
# <div class="tab-pane" id="licence" role="tabpanel">
# <ul class="licence" data-filter-tree="licence"> <li><span class="pass" data-group="licence" data-label="Search all images with an Open or Creative Commons Licence" data-value="1cc">Search all images with an Open or Creative Commons Licence</span></li><li><span class="pass" data-group="licence" data-label="Search all Public Domain images (PD and CC0)" data-value="2pd">Search all Public Domain images (PD and CC0)</span></li><li><span class="pass" data-group="licence" data-label="Search images with a Creative Commons licence" data-value="Search images with a Creative Commons licence">Search images with a Creative Commons licence</span><ul><li><span class="pass" data-group="licence" data-label="Any CC licence" data-value="Search images with a Creative Commons licence.0cc-only">Any CC licence</span></li><li><span class="pass" data-group="licence" data-label="Attribution (CC BY)" data-value="Search images with a Creative Commons licence.2cc-by">Attribution (CC BY)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-ShareAlike (CC BY-SA)" data-value="Search images with a Creative Commons licence.3cc-by-sa">Attribution-ShareAlike (CC BY-SA)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-NoDerivs (CC BY-ND)" data-value="Search images with a Creative Commons licence.4cc-by-nd">Attribution-NoDerivs (CC BY-ND)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-NonCommercial (CC BY-NC)" data-value="Search images with a Creative Commons licence.5cc-by-nc">Attribution-NonCommercial (CC BY-NC)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-NonCommercial-ShareAlike (CC BY-NC-SA)" data-value="Search images with a Creative Commons licence.6cc-by-nc-sa">Attribution-NonCommercial-ShareAlike (CC BY-NC-SA)</span></li><li><span class="pass" data-group="licence" data-label="Attribution-Non-Commercial-NoDerivs (CC BY-NC-ND)" data-value="Search images with a Creative Commons licence.7cc-by-nc-nd">Attribution-Non-Commercial-NoDerivs (CC BY-NC-ND)</span></li></ul></li><li><span class="pass" data-group="licence" data-label="About Creative Commons and image use" data-value="licence_url_a_image">About Creative Commons and image use</span></li><li><span class="pass" data-group="licence" data-label="Search for high resolution images available for commercial licensing" data-value="licence_url_b_shop">Search for high resolution images available for commercial licensing</span></li></ul> </div>
# </div>
# </div>
# <div class="hidden" id="filter-values">
# <input id="group_region" name="region" type="" value="Scotland">
# <input id="group_work_type" name="work_type" type="" value="Painting">
# <input id="group_category_title" name="category_title" type="" value="">
# <input id="group_style_title" name="style_title" type="" value="">
# <input id="group_licence" name="licence" type="" value="">
# <input id="group_category" name="category" type="" value="seas-and-coasts">
# <input class="field" id="location_latitude" name="location_latitude" type="hidden" value="">
# ...
# 						Maggie's Glasgow					</span>
# </div>
# </li>
# <!-- to do <li> should have 'icons' class if any icons are present and also have -->
# <li class="item artwork icons">
# <a class="" href="https://artuk.org/discover/artworks/haymaking-above-campbeltown-163913/view_as/grid/search/has_image:on--region:scotland--work_type:painting--category:seas-and-coasts/sort_by/date_earliest/order/asc/page/23" id="haymaking-above-campbeltown-163913" title="View artwork"></a>
# <div class="wrap">
# <div class="img-wrap">
# <img alt="Haymaking above Campbeltown" src="https://d3d00swyhr67nd.cloudfront.net/w300/collection/NSC/ABC/NSC_ABC_ABMS_2000_020-001.jpg"/>
# <div class="actions">
# <div class="action-toggle">
# <a class="toggle fav ajax-action no-user" data-action="fav-artwork" data-add-fav="" data-original-title="Sign in to favourite" data-placement="top" data-title-add="Add to favourites" data-title-remove="Remove from favourites" data-toggle="tooltip-hover" href="https://artuk.org/favourite/haymaking-above-campbeltown-163913" title=""></a>
# </div>
# <!-- skins/artuk/object/v_toolbar_curation-->
# <div class="album action-toggle toolbar_icon no-user" data-action-dropdown="">
# <div class="toggle album toolbar_icon" data-original-title="Sign in to curate" data-placement="top" data-toggle="tooltip-hover" title="Sign in to curate">
# </div>
# </div>
# <!-- skins/artuk/object/v_toolbar_curation-->
# </div>
# </div>
# <!-- -->
# </div>
#
# <div class="info">
# <div class="icons">
# </div>
# <span class="title">
# 											Haymaking above Campbeltown														</span>
# <span class="artist">
# 																E. Allan									</span>
# </div>
# <div class="more-info">
# <span class="title">
# 											Haymaking above Campbeltown														</span>
# <span class="artist">
# 						Campbeltown Museum					</span>
# </div>
# </li>
# <!-- END: skins/artuk/object/list/v_list -->
# <!-- skins/artuk/stories/v_list_close -->
# </ul>
# <!-- TO DO
# 	<div class="no-results">
# 		There are no results for your search, please try altering your search crietia.
# 	</div>
# 	-->
# <div class="back-top"></div>
# </section>
# <!-- skins/artuk/stories/v_list_close -->
# </main>
# <footer id="footer">
# <!-- common/v_footer -->
# <div class="container-break">
# <nav>
# <h2 class="sr-only">Follow us</h2>
# <ul class="menu menu-social">
# <li>
# <ul>
# <li class="facebook">
# <a class="ext_hlink" href="https://www.facebook.com/artukdotorg" target="_blank" title="Join us on Facebook">Join us on Facebook</a>
# </li>
# <li class="twitter">
# <a class="ext_hlink" href="https://twitter.com/artukdotorg" target="_blank" title="Follow us on Twitter">Follow us on Twitter</a>
# </li>
# <li class="instagram">
# <a class="ext_hlink" href="https://www.instagram.com/artukdotorg/" target="_blank" title="Follow us on Instagram">
# <svg enable-background="new 0 0 50 50" height="50px" id="Layer_0" version="1.1" viewbox="0 0 50 50" width="50px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path clip-rule="evenodd" d="M45.516,16.492c-0.101-2.196-0.448-3.697-0.958-5.011
# 										c-0.527-1.356-1.233-2.509-2.383-3.655c-1.146-1.148-2.299-1.854-3.657-2.381c-1.311-0.511-2.812-0.86-5.01-0.959
# 										c-2.203-0.101-2.905-0.125-8.512-0.125s-6.31,0.023-8.511,0.125c-2.197,0.099-3.698,0.449-5.011,0.959
# 										c-1.357,0.528-2.509,1.233-3.656,2.381c-1.148,1.146-1.854,2.299-2.381,3.655c-0.511,1.314-0.86,2.815-0.959,5.011
# 										c-0.101,2.202-0.125,2.906-0.125,8.512s0.023,6.309,0.125,8.512c0.1,2.197,0.449,3.697,0.959,5.01
# 										c0.528,1.358,1.233,2.51,2.381,3.657c1.147,1.147,2.299,1.854,3.656,2.382c1.313,0.511,2.814,0.858,5.011,0.959
# 										c2.202,0.101,2.905,0.125,8.511,0.125s6.309-0.024,8.512-0.125c2.197-0.101,3.699-0.448,5.01-0.959
# 										c1.358-0.528,2.511-1.234,3.657-2.382c1.149-1.147,1.855-2.299,2.383-3.657c0.51-1.312,0.857-2.812,0.958-5.01
# 										c0.101-2.203,0.125-2.905,0.125-8.512S45.616,18.693,45.516,16.492z M41.802,33.347c-0.094,2.011-0.431,3.105-0.713,3.833
# 										c-0.373,0.963-0.819,1.65-1.542,2.373s-1.412,1.17-2.375,1.544c-0.728,0.282-1.82,0.619-3.833,0.711
# 										c-2.177,0.1-2.83,0.121-8.343,0.121c-5.512,0-6.165-0.021-8.341-0.121c-2.014-0.092-3.107-0.429-3.833-0.711
# 										c-0.964-0.374-1.652-0.821-2.374-1.544c-0.723-0.723-1.169-1.41-1.544-2.373c-0.283-0.728-0.619-1.822-0.71-3.833
# 										c-0.1-2.179-0.121-2.83-0.121-8.343c0-5.512,0.021-6.166,0.121-8.342c0.091-2.013,0.427-3.106,0.71-3.833
# 										c0.375-0.963,0.822-1.652,1.544-2.373c0.722-0.723,1.41-1.169,2.374-1.544c0.727-0.284,1.82-0.62,3.833-0.71
# 										c2.176-0.1,2.829-0.121,8.341-0.121c5.513,0,6.164,0.021,8.343,0.121c2.013,0.09,3.105,0.427,3.833,0.71
# 										c0.963,0.375,1.652,0.822,2.375,1.544c0.723,0.721,1.169,1.41,1.542,2.373c0.282,0.728,0.619,1.82,0.713,3.833
# 										c0.098,2.176,0.119,2.83,0.119,8.342C41.921,30.517,41.899,31.168,41.802,33.347z" fill-rule="evenodd"></path>
# <circle clip-rule="evenodd" cx="36.018" cy="13.984" fill-rule="evenodd" r="2.478"></circle>
# <path clip-rule="evenodd" d="M24.996,14.403c-5.854,0-10.601,4.746-10.601,10.601
# 										c0,5.855,4.747,10.601,10.601,10.601c5.855,0,10.601-4.745,10.601-10.601C35.597,19.149,30.852,14.403,24.996,14.403z
# 										M24.996,31.886c-3.801,0-6.881-3.082-6.881-6.882c0-3.801,3.08-6.882,6.881-6.882c3.802,0,6.882,3.081,6.882,6.882
# 										C31.878,28.804,28.798,31.886,24.996,31.886z" fill-rule="evenodd"></path>
# </g>
# </svg>
# </a>
# </li>
# <li class="youtube">
# <a class="ext_hlink" href="https://www.youtube.com/channel/UCeZPrwByVwluSMQKgNLvnkw" target="_blank" title="Follow us on YouTube">Follow us on YouTube</a>
# </li>
# <li class="apple-podcasts">
# <a class="ext_hlink" href="https://itunes.apple.com/gb/podcast/art-matters/id1343288276?mt=2 " target="_blank" title="Find us on Apple Podcasts">
# <svg enable-background="new 0 0 50 50" height="50px" id="Layer_1" version="1.1" viewbox="0 0 50 50" width="50px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M28.941,29.207c-0.817-0.861-2.252-1.416-3.945-1.416c-1.695,0-3.129,0.552-3.947,1.416
# 										c-0.418,0.42-0.675,0.977-0.722,1.566c-0.139,1.271-0.061,2.369,0.087,4.119c0.142,1.668,0.411,3.895,0.763,6.16
# 										c0.25,1.611,0.455,2.482,0.639,3.107c0.299,1.009,1.422,1.895,3.177,1.895c1.755,0,2.876-0.884,3.178-1.895
# 										c0.185-0.624,0.39-1.493,0.64-3.107c0.354-2.267,0.621-4.49,0.764-6.16c0.148-1.75,0.227-2.848,0.087-4.119
# 										C29.615,30.184,29.359,29.627,28.941,29.207z M20.543,21.529c0,2.463,1.996,4.457,4.457,4.457c2.46,0,4.456-1.995,4.456-4.457
# 										c0-2.461-1.995-4.456-4.456-4.456C22.54,17.073,20.543,19.07,20.543,21.529z M24.945,3.945C14.525,3.975,5.986,12.428,5.857,22.848
# 										C5.752,31.289,11.14,38.51,18.665,41.154c0.135,0.048,0.281-0.022,0.329-0.157c0.014-0.039,0.018-0.081,0.012-0.122
# 										c-0.1-0.656-0.192-1.312-0.277-1.962c-0.029-0.229-0.176-0.425-0.386-0.519C12.2,35.714,8.252,29.626,8.309,22.925
# 										c0.088-9.065,7.492-16.457,16.557-16.53c9.267-0.074,16.833,7.444,16.833,16.694c-0.008,6.644-3.946,12.653-10.035,15.308
# 										c-0.212,0.095-0.357,0.289-0.389,0.519c-0.086,0.655-0.178,1.308-0.275,1.96c-0.021,0.139,0.072,0.271,0.213,0.29
# 										c0.042,0.008,0.085,0.004,0.124-0.013c7.452-2.619,12.81-9.729,12.81-18.065C44.146,12.516,35.527,3.917,24.945,3.945z
# 										M24.6,12.729c5.731-0.22,10.558,4.248,10.777,9.98c0.004,0.129,0.007,0.258,0.007,0.387c0.003,2.866-1.186,5.604-3.278,7.562
# 										c-0.172,0.16-0.263,0.389-0.252,0.623c0.041,0.712,0.025,1.404-0.021,2.186c-0.008,0.141,0.099,0.26,0.237,0.268
# 										c0.057,0.004,0.111-0.014,0.156-0.043c3.506-2.387,5.604-6.354,5.605-10.596c-0.007-7.09-5.759-12.83-12.848-12.824
# 										c-0.161,0-0.323,0.002-0.484,0.01c-6.786,0.263-12.231,5.857-12.317,12.648c-0.054,4.301,2.051,8.344,5.606,10.764
# 										c0.114,0.078,0.27,0.05,0.348-0.063c0.031-0.047,0.047-0.104,0.043-0.159c-0.051-0.729-0.059-1.46-0.022-2.188
# 										c0.013-0.234-0.079-0.463-0.25-0.624c-2.165-2.022-3.357-4.88-3.274-7.841C14.798,17.361,19.147,12.96,24.6,12.729z"></path>
# </g>
# </svg>
# </a>
# </li>
# <li class="dots">
# <a class="ext_hlink" href="https://the-dots.com/pages/art-uk-123427" target="_blank" title="Find us on Dots">
# <svg enable-background="new 0 0 50 50" height="50px" id="Layer_2" version="1.1" viewbox="0 0 50 50" width="50px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path clip-rule="evenodd" d="M25,4.254C13.56,4.254,4.253,13.561,4.253,25S13.56,45.746,25,45.746
# 										c11.439,0,20.747-9.307,20.747-20.746S36.439,4.254,25,4.254z M25,43.229C14.948,43.229,6.771,35.051,6.771,25
# 										C6.771,14.948,14.948,6.771,25,6.771c10.051,0,18.229,8.178,18.229,18.229C43.229,35.051,35.051,43.229,25,43.229z" fill-rule="evenodd"></path>
# <circle clip-rule="evenodd" cx="25" cy="25" fill-rule="evenodd" r="2.527"></circle>
# <circle clip-rule="evenodd" cx="25" cy="17.417" fill-rule="evenodd" r="2.528"></circle>
# <circle clip-rule="evenodd" cx="17.417" cy="25" fill-rule="evenodd" r="2.527"></circle>
# <circle clip-rule="evenodd" cx="32.583" cy="25" fill-rule="evenodd" r="2.527"></circle>
# <circle clip-rule="evenodd" cx="25" cy="32.583" fill-rule="evenodd" r="2.528"></circle>
# </g>
# </svg>
# </a>
# </li>
# <li class="to-top"><a data-anchor="#header" href="#header" id="to-top">Top</a></li>
# </ul>
# </li>
# <li class="support subscribe">
# <a class="ext_hlink" href="https://artuk.org/about/subscribe-to-newsletter" title="Subscribe to newsletter ">Subscribe to newsletter</a>
# </li>
# <li class="support">
# <a class="ext_hlink" href="https://artuk.org/support-us/make-a-donation" target="_blank" title="Donate to Art UK ">Donate to Art UK</a>
# </li>
# </ul>
# <h2 class="sr-only">Quick links</h2>
# <ul class="menu menu-quick">
# <li>
# <a class="hlink" href="https://artuk.org/about/contact-us" title="Contact us">Contact us</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/faq" title="Go toFAQ">FAQ</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/terms-of-use" title="Go toTerms of use">Terms of use</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/privacy-policy" title="Go toPrivacy policy">Privacy policy</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/use-of-cookies-14" title="Go toUse of cookies">Use of cookies</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/copyright-notice-15" title="Go toCopyright notice">Copyright notice</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/disclaimer-17" title="Go toDisclaimer">Disclaimer</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/accessibility" title="Go toAccessibility">Accessibility</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/about/jobs" title="Go toJobs">Jobs</a>
# </li>
# </ul>
# <ul class="menu menu-quick">
# <li>
# <a class="hlink" href="https://artuk.org/shop" title="Go toShop">Shop</a>
# </li>
# <li>
# <a class="hlink" href="http://artuk.org/shop/contact.html" title="Go toShop contact">Shop contact</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/shop-terms-of-use-and-supply" title="Go toShop terms of use and supply">Shop terms of use and supply</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/shop/about/delivery-details.html" title="Go toDelivery details">Delivery details</a>
# </li>
# <li>
# <a class="hlink" href="https://artuk.org/footer/website-credits" title="Go toWebsite credits">Website credits</a>
# </li>
# </ul>
# <ul class="menu menu-logo">
# <li>
# <h2 class="sr-only">Supported by</h2>
# <a class="ext_hlink" href="http://www.artscouncil.org.uk" target="_blank" title="Visit Arts Council website">
# <b hidden="">Arts Council</b><img alt="Arts Council" src="https://artuk.org/skins/artuk/img/footer-sponsors.png"/>
# </a>
# </li>
# <li class="heritage_logo">
# <img alt="heritage fund" src="https://artuk.org/skins/artuk/img/heritage-fund.png"/>
# </li>
# <li class="bloomberg_logo">
# <img alt="bloomberg" src="https://artuk.org/skins/artuk/img/bloomberg-white.png"/>
# </li>
# </ul>
# </nav>
# <div class="credits">
# <div class="trademark">
# <img src="https://artuk.org/skins/artuk/img/artuk-logo-white.png"/>® is a registered trade mark of the Public Catalogue Foundation.		</div>
# <div class="company">Art UK is the operating name of the Public Catalogue Foundation, a charity registered in England and Wales (1096185) and Scotland (SC048601).</div>
# </div>
# </div>
# <!-- END: common/v_footer --> </footer>
# <div class="bg-overlay"></div>
# <script type="text/javascript"> var show_survey_modal = false;</script>
# <script type="text/javascript">var show_survey_modal = true;</script>
# <div class="modal fade" id="survey-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <button aria-label="Close" class="close icon-close" data-dismiss="modal" type="button"></button>
# <div class="modal-body">
# <h1><center>Subscribe to our newsletter</center></h1>
# <img alt="(detail), c.1699, oil on canvas by Edwaert Collier (c.1640–c.1707)" class="img-responsive" src="https://d3d00swyhr67nd.cloudfront.net/w800h800/artuk/TATE_TATE_T03853_10_detail (1).jpg">
# <br/>
# <p><center>New stories, newly added artworks and shop offers delivered straight to your inbox every week.</center></p>
# <a class="btn btn-lg btn-primary" href="https://artuk.org/about/subscribe-to-newsletter" id="survey-link" target="_blank">Subscribe</a>
# <br/>
# <div class="center">
# <a class="link" href="#" id="no-thanks"><span>No thanks</span></a>
# </div>
# <br/>
# </img></div>
# </div>
# </div>
# </div>
# <script>
# 				var KT = {
# 		    config: {
# 		        base_url: "https://artuk.org/",
# 		        skin: "skins/artuk",
# 		        is_mobile: "",
# 		        http_protocol: "https://",
# 		        autocomplete: {
# 		        	api_url: "https://artuk.org/api/autocomplete",
# 		        	char_limit: 3,
# 		        	results_limit: 3,
# 		        	lang: {
# 			        	events: "Event",
# 						locations: "Venue",
# 						makers: "Artist",
# 						people: "People",
# 						places: "Places",
# 						terms: "Tags",
# 						works: "Title",
# 						additional: "Additional title information",
# 						identifier: "Accession number",
# 						acquisition: "Acquisition method",
# 						execution: "Execution date",
# 						medium: "Medium and support",
# 						description: "Description",
# 						artists: "Artist",
# 						collections: "Collection",
# 						address_postcode: "Postcode",
# 						postcode: "Postcode",
# 						curation: "Curation title",
# 						artist: "Artist",
# 						artwork: "Artwork",
# 						author: "Curated by",
# 						lrresource: "Title",
# 						lrartist: "Artist",
# 						lrtopic: "Topic",
# 						lrterm: "Art term"
#
# 		        	}
# 		        },
# 		        map_listing: {
# 		        	venues_api: "https://artuk.org/api/venues/object",
# 		        },
# 		        artwork_suffle_api: "https://artuk.org/discover/artworks",
#             google_maps_key: "AIzaSyAM99sM9aNS0rxwAhwsDijCc718PoGrge4",
# 		        cluster_gridSize: 65 // The grid size of a cluster in pixels.
# 		    },
# 		    lang: {
# 				p_artwork_drag_image_or_click_here: "Drag and drop or click this message to add images",
# 		    	p_val_error_artwork_img_size: "Image must be a minimum of 1,200 pixels in width or height",
# 		    	p_val_error_venue_logo_img_size:  "Image must be a minimum of 450 pixels in height"
# 		    },
# 		    subscribe_popup: true		};
# 		</script>
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyAM99sM9aNS0rxwAhwsDijCc718PoGrge4&amp;libraries=places&amp;v=weekly"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/lib_boundle.min.js?v=4.8.0"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/main_es6_boundle.min.js?v=4.8.0"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/main_boundle.min.js?v=4.8.0"></script>
# <script src="https://artuk.org/skins/artuk/assets/js/portal_boundle.min.js?v=4.8.0"></script>
# <script src="https://cdn.rawgit.com/toopay/bootstrap-markdown/master/js/bootstrap-markdown.js"></script>
# <script data-require="marked@*" data-semver="0.3.1" src="https://cdnjs.cloudflare.com/ajax/libs/marked/0.3.1/marked.js"></script>
# </body>
# </html>

# %%
# attributes of all images on the page
all_images = [node for node in all_results.findAll('li', {"class": "item artwork icons"})]
len(all_images)
# Out:
# 455

# %% [markdown]
# ### Artuk dataframe

# %% [markdown]
# #### create dataset (first time)

# %%
# removes all '\t' & '\n'
def remove_weird_chars(string):
    clean_string = string.replace('\n', '')
    clean_string = clean_string.replace('\t', '')
    return clean_string.strip()

def get_title(n):
    title = all_images[n].find('span', {"class": "title"})
    cleaned_title = remove_weird_chars(title.contents[0])
    if cleaned_title == 'Untitled':
        return np.nan
    return cleaned_title

def get_URL(n):
    embeded_url = all_images[n].find('a', {"class": ""})
    embeded_url = embeded_url.attrs['href']
    return embeded_url

def split_name_year(string):
    if '(' not in string: 
        return [string.strip()]
    split_string = string.split('(')
    split_string[0] = split_string[0].strip()
    split_string[1] = ('(' + split_string[1]).strip()
    return split_string

def get_artist_name(n):
    tag = all_images[n].find('span', {"class": "artist"})
    tag = remove_weird_chars(tag.contents[0])
    
    
    if tag == "unknown artist":
        return np.nan

    artist_name_and_date = split_name_year(tag)
    artist_name = artist_name_and_date[0]
    return artist_name

def get_art_year(n):
    tag = all_images[n].find('span', {"class": "date"})
    if tag is None:
        return np.nan
    tag = remove_weird_chars(tag.contents[0])
    return str(tag)

def dimension_text_to_num(string):
    clean_string = string.replace('cm', '')
    clean_string = clean_string.replace('H', '')
    clean_string = clean_string.replace('W', '')
    clean_string = clean_string.replace('(E)', '')
    clean_string = clean_string.split('x')
    return [float(clean_string[0].strip()), float(clean_string[1].strip())]

def year_to_estimate(creation_year):
    if creation_year is np.nan:
        return np.nan
    
    elif any(x in creation_year for x in ["-", "–"]):
        split_string = creation_year.split('–')
        
        start_filter = filter(str.isdigit, split_string[0])
        start = "".join(start_filter)
        
        end_filter = filter(str.isdigit, split_string[1])
        end = "".join(end_filter)
        
        start = start.strip()
        end = end.strip()
        avg = int(start) + int(end)
        avg = round(avg / 2)
        return str(avg)
    
    elif any(x in creation_year for x in ["th", "C"]):
        numeric_filter = filter(str.isdigit, creation_year)
        numeric_string = "".join(numeric_filter) + "00"
        return numeric_string.strip()
    
    else:
        numeric_filter = filter(str.isdigit, creation_year)
        numeric_string = "".join(numeric_filter)
        return numeric_string.strip()

# get_all_other & set_all_other sets: the enlarged imaged url, height and width, Accession number, medium
# as they are all in the embedded url, getting them all at once to increase speed
async def get_all_other(session, n):
    async with session.get(art_uk_df['url'][n]) as resp:
        page = await resp.text()
        embeded_page =  BeautifulSoup(page, 'html.parser')
        
        all_info = embeded_page.find('div', {'class' : 'masonry_details'})
        items = all_info.findAll('div', {'class' : 'masonry-item'})
        
        for tag in items:
            # Medium
            if tag.findNext('h5').text == "Medium":
                medium = tag.findNext('h5').findNext('p').text
                
            # Height and Width
            elif tag.findNext('h5').text == "Measurements":
                height = dimension_text_to_num(tag.findNext('h5').findNext('p').text)[0]
                width = dimension_text_to_num(tag.findNext('h5').findNext('p').text)[1]

            # Accession Number
            elif tag.findNext('h5').text == "Accession number":
                accession_number = tag.findNext('h5').findNext('p').text.replace('/', '_').replace(':', '_')
        
        # image_url
        if embeded_page.find('img', {"alt": art_uk_df['Title'][n]}) is None:
            enlarged_img = embeded_page.find('img', {"alt": "Untitled"})
            enlarged_img = enlarged_img.attrs['src'] 
        else:
            enlarged_img = embeded_page.find('img', {"alt": art_uk_df['Title'][n]})
            enlarged_img = enlarged_img.attrs['src'] 
        return [medium, height, width, accession_number, enlarged_img]
    
async def set_all_other():
     async with aiohttp.ClientSession() as session:
        tasks = []
        
        for number in range(len(all_images)):
            tasks.append(asyncio.ensure_future(get_all_other(session, number)))
                
        tasks = await asyncio.gather(*tasks)
        
        # image_url
        art_uk_df['Medium'] = [tasks[n][0] for n in range(len(all_images))]
        art_uk_df['height_cm'] = [tasks[n][1] for n in range(len(all_images))]
        art_uk_df['width_cm'] = [tasks[n][2] for n in range(len(all_images))]
        art_uk_df['Accession_number'] = [tasks[n][3] for n in range(len(all_images))]
        art_uk_df['img_URL'] = [tasks[n][4] for n in range(len(all_images))]
        
def create_artuk_df(): 
    # Title
    art_uk_df['Title'] = [get_title(n) for n in range(len(all_images))]
    
    # embedded url
    art_uk_df['url'] = [get_URL(n) for n in range(len(all_images))]
    
    # Artist Name
    art_uk_df['Artist'] = [get_artist_name(n) for n in range(len(all_images))]
    
    # Art Creation Date
    art_uk_df['Creation_Date'] = [get_art_year(n) for n in range(len(all_images))]
    
    art_uk_df['estimate_year'] = [year_to_estimate(art_uk_df['Creation_Date'][n]) for n in range(len(all_images))]

# %% [markdown]
# ##### import or create new df

# %%
artUK_collection = Path(r'artUK-collection.csv')

# if csv exist, then just import
if artUK_collection.is_file():
    art_uk_df = pd.read_csv(artUK_collection)
    
# create dataset
else:
    # new df, set new columns
    art_uk_df = pd.DataFrame(columns = ['Title', 'Artist', 'Creation_Date', 'estimate_year', 'url', 
                                        'img_URL', 'Medium', 'height_cm', 'width_cm', 'Accession_number', 
                                        'recoloured_image', 'colour_palette', 'relative_frequencies'])
    create_artuk_df()
    
    timer = time.process_time()
    await set_all_other()
    print(time.process_time() - timer)
    
    # export
    art_uk_df.to_csv(artUK_collection, index = False)

# %% [markdown]
# ##### Download all images to one folder

# %%
async def get_img(n):
    savepath = Path("ArtUK_scotland_seas_coasts/" + str(art_uk_df["Accession_number"][n]) + ".jpg")
    if not savepath.is_file():
        urllib.request.urlretrieve(art_uk_df['img_URL'][n], savepath)
    await asyncio.sleep(1)
    
async def download_All():
        tasks = []
        for number in range(len(all_images)):
            tasks.append(asyncio.ensure_future(get_img(number)))
        await asyncio.gather(*tasks)

timer = time.process_time()
await download_All()
print(time.process_time() - timer)
# Out:
# 0.0625

# %% [markdown]
# ##### Get color palettes

# %% [raw]
# took ~31.05 mins to extract colors for 455 images
# or 1863.015625 seconds
# and 4.1 second per image

# %%
async def get_colors(n):
    savepath = Path("ArtUK_scotland_seas_coasts/" + str(art_uk_df["Accession_number"][n]) + ".jpg")
    if savepath.is_file():
        recoloured_image, colour_palette, relative_frequencies = model.generate_colour_palette_from_image(savepath)
        await asyncio.sleep(1)
        return recoloured_image, colour_palette, relative_frequencies
    else:
        return np.nan, np.nan, np.nan
    
async def set_all_colors():
    tasks = []
    for number in range(len(all_images)):
        tasks.append(asyncio.ensure_future(get_colors(number)))

    await asyncio.gather(*tasks)
    art_uk_df['recoloured_image'] = [tasks[n].result()[0] for n in range(len(all_images))]
    art_uk_df['colour_palette'] = [tasks[n].result()[1] for n in range(len(all_images))]
    art_uk_df['relative_frequencies'] = [tasks[n].result()[2] for n in range(len(all_images))]
        
# timer = time.process_time()
# await set_all_colors()
# print(time.process_time() - timer)
# art_uk_df.to_csv(artUK_collection, index = False)

# %% [markdown]
# ##### Update

# %% [raw]
# update all coloumns APART FROM the color palettes

# %%
create_artuk_df()
timer = time.process_time()
await set_all_other()
print(time.process_time() - timer)
# Out:
# 43.390625

# %% [raw]
# update ONLY color palettes, It takes a very long time so uncommented unless you have updated columns

# %%
# await set_all_colors()
# print(time.process_time() - timer)
# art_uk_df.to_csv(artUK_collection, index = False)

# %% [raw]
# export to csv

# %%
art_uk_df.to_csv(artUK_collection, index = False)

# %%
art_uk_df
# art_uk_df[art_uk_df["Creation_Date"].str.contains("later|after|before", na = False)]
# Out:
#                                                  Title  \
# 0                                  The Dream of Joseph
# 1                                   A Scottish Warship
# 2                                  Ships in a Calm Sea
# 3                              Fishing Boats in a Calm
# 4    A Mountainous Coastal Landscape with Classical...
# ..                                                 ...
# 450                                            Estuary
# 451                                    Cargo for Power
# 452                           Raised Beaches, Colonsay
# 453                   Trees in a Golden Field and Sea*
# 454                        Haymaking above Campbeltown
#
#                      Artist Creation_Date estimate_year  \
# 0           Paolo Fiammingo   c.1587–1596          1592
# 1                       NaN     1650–1674          1662
# 2    Willem van de Velde II       c.1660s          1660
# 3    Willem van de Velde II          1658          1658
# 4                Jean Daret          1661          1661
# ..                      ...           ...           ...
# 450             Ralph Cowan           NaN           NaN
# 451       Kenneth M. Sibley           NaN           NaN
# 452         John Cunningham           NaN           NaN
# 453                     NaN           NaN           NaN
# 454                E. Allan           NaN           NaN
#
#                                                    url  \
# 0    https://artuk.org/discover/artworks/the-dream-...
# 1    https://artuk.org/discover/artworks/a-scottish...
# 2    https://artuk.org/discover/artworks/ships-in-a...
# 3    https://artuk.org/discover/artworks/fishing-bo...
# 4    https://artuk.org/discover/artworks/a-mountain...
# ..                                                 ...
# 450  https://artuk.org/discover/artworks/estuary-15...
# 451  https://artuk.org/discover/artworks/cargo-for-...
# 452  https://artuk.org/discover/artworks/raised-bea...
# 453  https://artuk.org/discover/artworks/trees-in-a...
# 454  https://artuk.org/discover/artworks/haymaking-...
#
#                                                img_URL         Medium  \
# 0    https://d3d00swyhr67nd.cloudfront.net/w944h944...  oil on canvas
# 1    https://d3d00swyhr67nd.cloudfront.net/w1200h12...  oil on canvas
# 2    https://d3d00swyhr67nd.cloudfront.net/w1200h12...   oil on panel
# 3    https://d3d00swyhr67nd.cloudfront.net/w1200h12...  oil on canvas
# 4    https://d3d00swyhr67nd.cloudfront.net/w944h944...  oil on canvas
# ..                                                 ...            ...
# 450  https://d3d00swyhr67nd.cloudfront.net/w1200h12...   oil on board
# 451  https://d3d00swyhr67nd.cloudfront.net/w1200h12...   oil on board
# 452  https://d3d00swyhr67nd.cloudfront.net/w944h944...  oil on canvas
# 453  https://d3d00swyhr67nd.cloudfront.net/w1200h12...  oil on canvas
# 454  https://d3d00swyhr67nd.cloudfront.net/w1200h12...  oil on canvas
#
#      height_cm  width_cm Accession_number  \
# 0        160.0     116.8             1591
# 1         82.4      98.7      ABDAG001234
# 2         36.8      49.9          NG 1947
# 3         41.9      56.2           EU0744
# 4         99.7     138.7              212
# ..         ...       ...              ...
# 450       87.3     114.5       GLAEX A113
# 451       30.7      59.5      ABDAG008033
# 452       73.8      83.8       GLAEX A302
# 453       44.0      58.0           065466
# 454       40.4      67.7  A&BMS_ 2000.020
#
#                                       recoloured_image  \
# 0    [[[32 21 10]\n  [32 21 10]\n  [32 21 10]\n  .....
# 1    [[[138 120 106]\n  [138 120 106]\n  [173 171 1...
# 2    [[[201 183 125]\n  [201 183 125]\n  [201 183 1...
# 3    [[[185 180 155]\n  [185 180 155]\n  [185 180 1...
# 4    [[[ 76  55  36]\n  [ 76  55  36]\n  [ 76  55  ...
# ..                                                 ...
# 450  [[[192 174 163]\n  [192 174 163]\n  [192 174 1...
# 451  [[[ 61  75  80]\n  [102 121 126]\n  [102 121 1...
# 452  [[[140 169 169]\n  [140 169 169]\n  [140 169 1...
# 453  [[[181 208 224]\n  [181 208 224]\n  [181 208 2...
# 454  [[[105 131 134]\n  [ 73  71  54]\n  [ 73  71  ...
#
#                                         colour_palette  \
# 0    [array([32, 21, 10], dtype=uint8), array([79, ...
# 1    [array([193, 177, 166], dtype=uint8), array([2...
# 2    [array([201, 183, 125], dtype=uint8), array([2...
# 3    [array([185, 180, 155], dtype=uint8), array([2...
# 4    [array([48, 35, 22], dtype=uint8), array([98, ...
# ..                                                 ...
# 450  [array([192, 174, 163], dtype=uint8), array([1...
# 451  [array([102, 121, 126], dtype=uint8), array([6...
# 452  [array([159, 175, 161], dtype=uint8), array([1...
# 453  [array([239, 217, 120], dtype=uint8), array([1...
# 454  [array([160, 166, 150], dtype=uint8), array([9...
#
#                                   relative_frequencies
# 0    [0.4320212026416406, 0.1342225698065114, 0.112...
# 1    [0.2053546626984127, 0.16702132936507935, 0.10...
# 2    [0.23980818965517242, 0.19919181034482758, 0.1...
# 3    [0.3297661803217359, 0.15503367003367002, 0.12...
# 4    [0.3337676991150442, 0.2481637168141593, 0.178...
# ..                                                 ...
# 450  [0.4507961724266072, 0.11447324414715719, 0.09...
# 451  [0.41855353375527427, 0.10980617088607594, 0.1...
# 452  [0.2307903849568872, 0.17454766085909906, 0.08...
# 453  [0.19112026862026862, 0.15524928774928776, 0.1...
# 454  [0.2541690340909091, 0.14666193181818182, 0.09...
#
# [455 rows x 13 columns]
